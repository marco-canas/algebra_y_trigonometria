# %% [markdown]
# # Prompt para el diseño del segundo quiz de Álgebra y Trigonometría
#
# Diséñame un quiz de tres ítems obligatorios y uno opcional para evaluar el tema de ecuaciones de la sección 2.1 de Swokowski pero **sin** evaluar los temas de ecuaciones con expresiones racionales y **sin** evaluar el tema de aplicaciones de las ecuaciones. La estructura del quiz quiero que sea así:
# 1. El primer ítem donde evalúe a través de cinco preguntas, la teoría sobre definición de ecuación, ecuación lineal, ecuación cuadrática, propiedades de las igualdades y el método de transposición de términos para solución de  ecuaciones lineales.
# 2. Un segundo ítem sobre solución de ecuaciones equivalentes a ecuaciones lineales.
# 3. Un tercer punto sobre solución de ecuaciones equivalentes a ecuaciones cuadráticas por los métodos de completación del trinomio cuadrado perfecto, el método de factorización y uso de la propiedad de dominio entero de $(\mathbb{R}, + , \cdot)$ ($(ab = 0) \to (a = 0 \lor b = 0)$) y el método de la fórmula del bachiller o fórmula general: $\frac{-b \pm \sqrt{b^{2} - 4ac}}{2a}$.

# %% [markdown]
# Perfecto. Te propongo un **quiz diseñado paso a paso** en la estructura que me indicaste, ajustado a la **sección 2.1 de Swokowski**, excluyendo los temas de ecuaciones con expresiones racionales y de aplicaciones.
#
# ---
#
# # **Quiz – Ecuaciones (Sección 2.1, Swokowski)**
#
# **Nombre: \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_**
# **Fecha: \_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_\_**
# **Duración: 40 minutos**
#
# ---
#
# ### **Ítem 1. Conceptos fundamentales (5 preguntas cortas, 2 puntos cada una, total 10 puntos).**
#
# Responde de manera breve y clara.
#
# a) Define qué es una **ecuación**.
#
# b) Da la definición de una **ecuación lineal** en una variable y escribe un ejemplo.
#
# c) Da la definición de una **ecuación cuadrática** en una variable y escribe un ejemplo.
#
# d) Escribe dos **propiedades de la igualdad** que se usan en la solución de ecuaciones.
#
# e) Explica brevemente en qué consiste el **método de transposición de términos** para resolver ecuaciones lineales.
#
# ---
#
# ### **Ítem 2. Ecuaciones equivalentes a ecuaciones lineales (10 puntos).**
#
# Resuelve paso a paso:
#
# $$
# 3(x - 2) + 5 = 2x + 7
# $$
#
# Muestra claramente cómo se obtiene una ecuación equivalente en cada transformación hasta llegar a la solución final.
#
# ---
#
# ### **Ítem 3. Ecuaciones equivalentes a cuadráticas (20 puntos).**
#
# Resuelve cada ecuación usando el método que se indica:
#
# a) Usando **completación del trinomio cuadrado perfecto**:
#
# $$
# x^{2} + 6x + 5 = 0
# $$
#
# b) Usando **factorización y la propiedad de dominio entero de $(\mathbb{R}, +, \cdot)$**:
#
# $$
# x^{2} - 9 = 0
# $$
#
# c) Usando la **fórmula general (fórmula del bachiller)**:
#
# $$
# 2x^{2} - 3x - 2 = 0
# $$
#
# ---
#
# ### **Ítem Opcional (5 puntos).**
#
# Elige y resuelve:
#
# Resuelve la siguiente ecuación cuadrática **por el método que prefieras**:
#
# $$
# x^{2} + 4x + 1 = 0
# $$
#
# ---
#
# 👉 Con esta estructura el quiz es **claro, balanceado y alineado** con lo que pediste:
#
# * Ítem 1 mide teoría.
# * Ítem 2 mide práctica de ecuaciones lineales equivalentes.
# * Ítem 3 mide práctica de ecuaciones cuadráticas con distintos métodos.
# * Ítem opcional permite al estudiante demostrar dominio adicional.
#
# ---
#
# ¿Quieres que te prepare también la **rúbrica de calificación** con criterios (claridad, procedimientos correctos, resultado final) para que tus estudiantes tengan más transparencia en la evaluación?

# %% [markdown]
# ## Prompt para la conversión a archivo .docx
#
# Dame el script de Python para convertir este quiz en un archivo .docx pero sin utilizar lenguaje latex, pero utiliza lenguaje unicode para hacer legible las expresiones matemáticas

# %%
from docx import Document
from docx.shared import Pt

# Crear documento
doc = Document()

# Título del documento
doc.add_heading("Quiz – Ecuaciones (Sección 2.1, Swokowski)", level=0)

# Encabezado con datos
doc.add_paragraph("Nombre: _____________________________")
doc.add_paragraph("Fecha: _____________________________")
doc.add_paragraph("Duración: 40 minutos\n")

# Ítem 1
doc.add_heading("Ítem 1. Conceptos fundamentales (5 preguntas cortas, 2 puntos cada una, total 10 puntos).", level=1)
doc.add_paragraph("Responde de manera breve y clara.")

preguntas1 = [
    "a) Define qué es una ecuación.",
    "b) Da la definición de una ecuación lineal en una variable y escribe un ejemplo.",
    "c) Da la definición de una ecuación cuadrática en una variable y escribe un ejemplo.",
    "d) Escribe dos propiedades de la igualdad que se usan en la solución de ecuaciones.",
    "e) Explica brevemente en qué consiste el método de transposición de términos para resolver ecuaciones lineales."
]

for p in preguntas1:
    doc.add_paragraph(p, style="List Bullet")

# Ítem 2
doc.add_heading("Ítem 2. Ecuaciones equivalentes a ecuaciones lineales (10 puntos).", level=1)
doc.add_paragraph("Resuelve paso a paso la siguiente ecuación:")
doc.add_paragraph("   3(x − 2) + 5 = 2x + 7")

# Ítem 3
doc.add_heading("Ítem 3. Ecuaciones equivalentes a cuadráticas (20 puntos).", level=1)

doc.add_paragraph("a) Usando completación del trinomio cuadrado perfecto:")
doc.add_paragraph("   x² + 6x + 5 = 0")

doc.add_paragraph("b) Usando factorización y la propiedad de dominio entero de (ℝ, +, ·):")
doc.add_paragraph("   x² − 9 = 0")

doc.add_paragraph("c) Usando la fórmula general (fórmula del bachiller):")
doc.add_paragraph("   2x² − 3x − 2 = 0")

# Ítem Opcional
doc.add_heading("Ítem Opcional (5 puntos).", level=1)
doc.add_paragraph("Resuelve la siguiente ecuación cuadrática por el método que prefieras:")
doc.add_paragraph("   x² + 4x + 1 = 0")

# Guardar archivo
doc.save("quiz_ecuaciones.docx")
print("Archivo 'quiz_ecuaciones.docx' creado con éxito.")
# Out:
# Archivo 'quiz_ecuaciones.docx' creado con éxito.
