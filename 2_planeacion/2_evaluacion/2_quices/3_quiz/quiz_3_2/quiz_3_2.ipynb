# %% [markdown]
# # Prompt para el diseño del quiz 3 de la unidad 2 del texto de Álgebra y Trigonometría de Swokowski
#
# Dame por favor, un diseño de un quiz de 8 preguntas para evaluar los temas vistos en la unidad 2 del texto de Álgebra y Trigonometría de Swokowski. Cada pregunta debe ser clara y concisa, y debe cubrir uno de los temas listados a continuación. Asegúrate de que las preguntas sean variadas y aborden diferentes aspectos de cada tema.
#
# Temas a evaluar:
#
# 1. Ecuaciones lineales $ax + b = 0$.
# 2. Mostrar que dos ecuaciones no son equivalentes.
# 3. Mostrar que una ecuación no tiene solución.
# 4.  Relación entre escalas de temperatura: La relación entre las escalas Celsius y Fahrenheit de temperatura está dada por $$C = \frac{5}{9}(F - 32)$$
#    a. Si la temperatura es de 68°F, ¿cuál es la temperatura en °C?
#    b. Despeje F.  y responda: Si la temperatura es de 20°C, ¿cuál es la temperatura en °F?
#    c. ¿A qué temperatura son iguales las dos escalas?
#
# 5. Ecuaciones cuadráticas $ax^2 + bx + c = 0$.
# 6. Deduzca, utilizando el método de completación del trinomio cuadrado perfecto, la solución general de la ecuaciónb cuadrática $x^2 + bx + c = 0$. Ojo, el coeficiente líder es 1.
# 7. Ecuaciones racionales $\frac{P(x)}{Q(x)} = 0$.
# 8. Mezcla de productos químicos
# Un químico tiene 10 mililitros de una solución que contiene una concentración
# al 30% de ácido. ¿Cuántos mililitros de ácido puro deben agregarse para
# aumentar la concentración al 50%?
# 1. Inecuaciones lineales $ax + b < 0$.
# 2. Inceuaciones racionales $\frac{P(x)}{Q(x)} < 0$.

# %% [markdown]
# Aquí tienes un **quiz de 8 preguntas**, cada una alineada con los temas listados de la Unidad 2 de *Álgebra y Trigonometría* de Swokowski. He formulado enunciados claros, concisos y variados, para que los estudiantes demuestren comprensión conceptual y habilidad de resolución.
#
# ---
#
# # **Quiz Unidad 2 – Álgebra y Trigonometría (Swokowski)**
#
# **Tiempo:** 50 minutos
# **Número de preguntas:** 8
#
# ---

# %% [markdown]
# ### **1. Ecuaciones lineales**
#
# Resuelva la ecuación lineal:
#
# $$
# 7x - 21 = 0
# $$
#
# ---

# %% [markdown]
# ### **2. No equivalencia de ecuaciones**
#
# Determine si las siguientes dos ecuaciones son equivalentes. Justifique su respuesta.
#
# $$
# 2(x - 3) = 10
# \quad \text{y} \quad
# x - 3 = 5
# $$
#
# ---

# %% [markdown]
# ### **3. Ecuación sin solución**
#
# Muestre que la siguiente ecuación no tiene solución:
#
# $$
# 4(x + 1) = 4x + 10
# $$
#
# ---

# %% [markdown]
# ### **4. Relación entre escalas de temperatura**
#
# La relación entre las escalas Celsius y Fahrenheit está dada por:
#
# $$
# C = \tfrac{5}{9}(F - 32)
# $$
#
# a. Convierta $68^\circ F$ a grados Celsius.
# b. Despeje $F$ en términos de $C$. Luego, convierta $20^\circ C$ a grados Fahrenheit.
# c. Determine la temperatura para la cual ambas escalas son iguales.
#
# ---

# %% [markdown]
# ### **5. Ecuaciones cuadráticas**
#
# Resuelva la ecuación cuadrática:
#
# $$
# 3x^2 - 5x - 2 = 0
# $$
#
# ---

# %% [markdown]
# ### **6. Completación del trinomio cuadrado perfecto**
#
# Deduzca la fórmula general para resolver la ecuación:
#
# $$
# x^2 + bx + c = 0
# $$
#
# utilizando el método de completación del trinomio cuadrado perfecto.
#
# ---

# %% [markdown]
# ### **7. Ecuaciones racionales**
#
# Resuelva la siguiente ecuación racional:
#
# $$
# \frac{x - 2}{x + 3} = 0
# $$
#
# ---

# %% [markdown]
# ### **8. Problema aplicado de mezcla química**
#
# Un químico tiene 1 litro de una solución que contiene ácido al 10%.
# ¿Cuántos mililitros de ácido puro deben agregarse para que la concentración aumente al 60%?
#
# ---
# Nota: utilice, que en este caso la concentración se define como la cantidad de ácido puro dividido entre el volumen total de la solución. Es decir,
#
# $$
# C = \frac{\text{Volumen de ácido}}{\text{Volumen de la solución.}}
# $$

# %% [markdown]
# Perfecto, Marco 🚀.
# Te preparo una **guía didáctica** que combina **explicación paso a paso en LaTeX** (para que la puedas mostrar como apunte en clase) y una **solución computacional en Python** (para verificar el resultado y motivar el uso de herramientas digitales).
#
# ---
#
# # 📘 Guía Didáctica
#
# ## Problema
#
# > Un químico tiene 1 litro de una solución que contiene ácido al 10%.
# > ¿Cuántos mililitros de ácido puro deben agregarse para que la concentración aumente al 60%?
#
# ---
#
# ## ✍️ Planteamiento matemático (en LaTeX)
#
# ```latex
# \section*{Planteamiento del problema}
#
# Tenemos una solución de $1$ litro (equivalente a $1000$ mL) que contiene ácido al $10\%$.
#
# \begin{itemize}
#     \item Volumen inicial de la solución: $1000$ mL.
#     \item Concentración inicial: $10\%$.
#     \item Ácido presente inicialmente:
#     \[
#         0.10 \times 1000 = 100 \, \text{mL}.
#     \]
#     \item Sea $x$ la cantidad (en mL) de ácido puro que se agrega.
# \end{itemize}
#
# Después de agregar $x$ mililitros de ácido puro:
#
# \[
# \text{Ácido total} = 100 + x
# \]
# \[
# \text{Volumen total de la solución} = 1000 + x
# \]
#
# La nueva concentración debe ser del $60\%$:
#
# \[
# \frac{100 + x}{1000 + x} = 0.60
# \]
#
# ---
# \section*{Resolviendo la ecuación}
# Multiplicamos en cruz:
#
# \[
# 100 + x = 0.60 \cdot (1000 + x)
# \]
#
# \[
# 100 + x = 600 + 0.60x
# \]
#
# \[
# x - 0.60x = 600 - 100
# \]
#
# \[
# 0.40x = 500
# \]
#
# \[
# x = \frac{500}{0.40} = 1250
# \]
#
# ---
# \section*{Respuesta}
# Se deben agregar \textbf{1250 mL} de ácido puro.
# ```
#
# ---
#
# ## 🐍 Solución en Python
#
# ```python
# # ===========================================
# # Problema: Mezcla de soluciones químicas
# # ===========================================
#
# # Volumen inicial en mL
# V_inicial = 1000
#
# # Ácido puro inicial
# A_inicial = 0.10 * V_inicial
#
# # Cantidad a agregar (x)
# # Ecuación: (A_inicial + x) / (V_inicial + x) = 0.60
#
# import sympy as sp
#
# x = sp.symbols('x', positive=True)
# ecuacion = sp.Eq((A_inicial + x) / (V_inicial + x), 0.60)
#
# # Resolver
# solucion = sp.solve(ecuacion, x)[0]
# print(f"Se deben agregar {solucion} mL de ácido puro.")
# ```
#
# ---
#
# ## ✅ Resultado esperado
#
# ```
# Se deben agregar 1250.0 mL de ácido puro.
# ```
#
# ---

# %% [markdown]
# 👉 Esta guía te permite:
#
# * **En LaTeX**: mostrar la modelación algebraica del problema.
# * **En Python**: validar la respuesta con un método simbólico.
#
# ---
#
# ¿Quieres que te prepare esta guía en un **notebook Jupyter listo para tus clases**, con celdas de texto (Markdown + LaTeX) y celdas de código Python?

# %% [markdown]
# # Prompt para convertir a formato .docx
#
# Dame el script de Python para convertir en archivo .docx a este quiz, sin utilizar latex, y utilizando símbolos unicode para hacer legible mas expresiones matemáticas, por favor, presenta las expresiones fraccionarias con notación a dos líneas para facilitar su legibilidad.

# %%
from docx import Document

# Crear documento
doc = Document()
doc.add_heading("Quiz Unidad 2 – Álgebra y Trigonometría (Swokowski)", level=1)
doc.add_paragraph("Tiempo: 50 minutos")
doc.add_paragraph("Número de preguntas: 8")
doc.add_paragraph(" ")

# Pregunta 1
doc.add_paragraph("1. Resuelva la ecuación lineal:")
doc.add_paragraph("   7x − 21 = 0")

# Pregunta 2
doc.add_paragraph("2. Determine si las siguientes dos ecuaciones son equivalentes. Justifique su respuesta:")
doc.add_paragraph("   2(x − 3) = 10")
doc.add_paragraph("   x − 3 = 5")

# Pregunta 3
doc.add_paragraph("3. Muestre que la siguiente ecuación no tiene solución:")
doc.add_paragraph("   4(x + 1) = 4x + 10")

# Pregunta 4
doc.add_paragraph("4. La relación entre las escalas Celsius y Fahrenheit está dada por:")
doc.add_paragraph("       C =  5\n       ― (F − 32)\n       9")
doc.add_paragraph("   a) Convierta 68°F a grados Celsius.")
doc.add_paragraph("   b) Despeje F en términos de C. Luego convierta 20°C a grados Fahrenheit.")
doc.add_paragraph("   c) Determine la temperatura para la cual ambas escalas son iguales.")

# Pregunta 5
doc.add_paragraph("5. Resuelva la ecuación cuadrática:")
doc.add_paragraph("   3x² − 5x − 2 = 0")

# Pregunta 6
doc.add_paragraph("6. Deduzca la fórmula general para resolver la ecuación:")
doc.add_paragraph("   x² + bx + c = 0")
doc.add_paragraph("   utilizando el método de completación del trinomio cuadrado perfecto.")

# Pregunta 7
doc.add_paragraph("7. Resuelva la siguiente ecuación racional:")
doc.add_paragraph("       x − 2\n   ―――――― = 0\n       x + 3")

# Pregunta 8
doc.add_paragraph("8. Un químico tiene 10 ml de una solución que contiene ácido al 30%.")
doc.add_paragraph("   ¿Cuántos mililitros de ácido puro deben agregarse para que la concentración aumente al 50%?")

# Guardar archivo
doc.save("Quiz_Unidad2.docx")
