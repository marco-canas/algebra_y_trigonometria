# %% [markdown]
# # Prompt para el diseño del parcial 2
#
# Dame el diseño de una parcial de 7 puntos, de los cuales, 5 sean obligatorios y los dos restantes sean opcionales. El parcial es de Álgebra y Trigonometría, basado en el libro de Swokowski, y cubre las secciones 2.1 a la 2.7. El parcial debe incluir problemas que evalúen la comprensión de ecuaciones lineales, ecuaciones equivalentes, propiedades de las igualdades, ecuaciones con expresiones racionales, métodos de solución como uniformidad y transposición de términos, aplicaciones prácticas en escalas de temperatura y circuitos eléctricos, así como la capacidad para identificar cuando una ecuación no tiene solución o cuando una ecuación no es equivalente a la que la precede.
# Programa del curso: https://github.com/marco-canas/algebra_y_trigonometria/blob/main/1_plan_curso/1_programa_algebra_and_trigonometry.md
# Libro guía: [Álgebra y Trigonometría de Swokowski Edición 13](https://archive.org/details/algebra-y-trigonometria-con-geometria-analitica-13va-edicion-earl-w.-swokowski/page/n3/mode/2up)
#
# Secciones de Swokowski a evaluar:
#
# 2.1 Ecuaciones
# 2.2 Problemas de aplicación
# 2.3 Ecuaciones cuadráticas
# 2.4 Números complejos.
# 2.5 Otros tipos de ecuaciones.
# 2.6 Desigualdades.
# 2.7 Más sobre desigualdades.
#
# Temas a evaluar
#
# Ecuaciones lineales, Ecuaciones equivalentes, propiedades de las igualdades para obtener equiciones equivalentes, Ecuaciones con expresiones racionales, el método de uniformidad y el método de transposición de terminos para solución de ecuaciones lineales. Limitaciones del método de transposición de términos para resolver ecuaciones lineales, Ecuaciones con expresiones racionales que no tienen solución, Directrices para resolver ecuaciones que contengan expresiones racionales, Aplicaciones de las ecuaciones lineales y con expresiones racionales en escalas de temperatura y en circuitos eléctricos, Directrices para resolver problemas de aplicación de ecuaciones lineales y con expresiones racionales, .
#
# Saber determinar cuando no hay solución  o cuando la solución son todos los reales excepto uno de ellos:
#
# $$
# \frac{2x}{2x + 3} + \frac{6}{4x + 6} = 5
# $$
#
# $$
# \frac{2}{2x + 5} + \frac{3}{2x - 5} = \frac{10x + 5}{4x^{2} - 25}
# $$
#
#
# Saber determinar cuando una ecuación no es equivalente a la que la precede:
#
# $$ \begin{aligned} x^{2} - x - 2 & = x^{2} - 4 \\
# (x + 1)(x - 2) & = (x+2)(x -2) \\
# x + 1 & = x + 2 \\
# 1 & = 2
#  \end{aligned} $$
#
#
#
# $$ \begin{aligned}
# 5x + 6 & = 4x + 3 \\
# x^{2} + 5x + 6 & = x^{2} + 4x + 3 \\
# (x+2)(x+3) & = (x+1)(x+3) \\
# x + 2 & = x + 1 \\
# 2 & = 1
# \end{aligned} $$

# %% [markdown]
# Perfecto 🚀 Te propongo un **diseño de examen parcial de Álgebra y Trigonometría** (7 preguntas, 5 obligatorias y 2 opcionales) siguiendo los temas y secciones indicadas de *Swokowski, Álgebra y Trigonometría (2.1 – 2.7)*.
#
# ---
#
# # **Parcial de Álgebra y Trigonometría**
#
# **Duración:** 120 minutos
# **Número de preguntas:** 7 (las primeras 5 son obligatorias, las últimas 2 son opcionales).
#
# ### **Instrucciones:**
#
# 1. Resuelva cada ejercicio mostrando todos los pasos intermedios.
# 2. Justifique cuando una ecuación no tenga solución o cuando la solución sea un conjunto restringido.
# 3. En las preguntas opcionales, seleccione **solo una** para responder (se evaluará la de mayor puntaje).
#
# ---
#
# ## **Preguntas obligatorias**
#
# **1. (Ecuaciones lineales y transposición de términos – 15 puntos)**
# Resuelva la ecuación:
# [
# 5x - 7 = 3x + 9
# ]
#
# * Indique los pasos realizados mediante transposición de términos.
# * Verifique si el método de transposición conserva la equivalencia.
#
# ---
#
# **2. (Ecuaciones racionales y directrices – 20 puntos)**
# Resuelva la siguiente ecuación racional e indique si hay valores prohibidos:
# [
# \frac{2x}{2x + 3} + \frac{6}{4x + 6} = 5
# ]
#
# * Escriba claramente el conjunto solución.
# * Explique por qué en algunos casos las ecuaciones racionales no tienen solución.
#
# ---
#
# **3. (Ecuaciones equivalentes – 15 puntos)**
# Analice la siguiente secuencia de ecuaciones:
# [
# x^{2} - x - 2 = x^{2} - 4
# ]
# [
# (x + 1)(x - 2) = (x+2)(x -2)
# ]
# [
# x + 1 = x + 2
# ]
# [
# 1 = 2
# ]
#
# * Identifique en qué paso se perdió la equivalencia.
# * Explique por qué la última ecuación no es equivalente a la inicial.
#
# ---
#
# **4. (Aplicaciones: escalas de temperatura – 15 puntos)**
# La relación entre las escalas Celsius (°C) y Fahrenheit (°F) está dada por:
# [
# F = \frac{9}{5}C + 32
# ]
#
# * Exprese ( C ) en función de ( F ).
# * Convierta ( 20,^{\circ}C ) a grados Fahrenheit.
# * Convierta ( 212,^{\circ}F ) a grados Celsius.
#
# ---
#
# **5. (Aplicaciones: circuitos eléctricos – 20 puntos)**
# La ley de Ohm establece que ( V = IR ), donde:
#
# * ( V ) es el voltaje en voltios,
# * ( I ) es la corriente en amperios,
# * ( R ) es la resistencia en ohmios.
#
# Si un circuito tiene una resistencia de ( R = 12 , \Omega ) y un voltaje de ( V = 96 , V ):
#
# 1. Calcule la corriente ( I ).
# 2. Si se duplica la resistencia, ¿cuál es la nueva corriente?
# 3. Interprete físicamente la relación entre las variables.
#
# ---
#
# ## **Preguntas opcionales**
#
# **(Responda solo UNA, se calificará la de mayor puntaje).**
#
# **6. (Ecuaciones racionales con múltiples soluciones – 15 puntos)**
# Resuelva la ecuación:
# [
# \frac{2}{2x + 5} + \frac{3}{2x - 5} = \frac{10x + 5}{4x^{2} - 25}
# ]
#
# * Determine si existe restricción en el dominio.
# * Indique si la ecuación tiene solución, no tiene solución, o si todas menos una son solución.
#
# ---
#
# **7. (Desigualdades – 15 puntos)**
# Resuelva la desigualdad:
# [
# \frac{x - 2}{x + 1} \leq 0
# ]
#
# * Indique claramente el conjunto solución en notación de intervalos.
# * Represente gráficamente el conjunto solución en la recta real.
#
# ---
#
# 📌 **Distribución de puntaje total: 100 puntos.**
#
# * Preguntas obligatorias (1–5): 85 puntos.
# * Pregunta opcional (6 o 7): 15 puntos.
#
# ---
#
# ¿Quieres que además te prepare un **script en Python** para generar este parcial automáticamente en `.docx` (con símbolos Unicode en vez de LaTeX), como hicimos antes con el de lógica?
