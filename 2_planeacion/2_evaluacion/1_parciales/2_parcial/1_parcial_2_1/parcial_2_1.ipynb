# %% [markdown]
# # Prompt para el diseño del parcial 2
#
# Dame el diseño de una parcial de 7 puntos, de los cuales, 5 sean obligatorios y los dos restantes sean opciaonales. El parcial es de Álgebra y Trigonometría, basado en el libro de Swokowski, y cubre las secciones 2.1 a la 2.7. El parcial debe incluir problemas que evalúen la comprensión de ecuaciones lineales, ecuaciones equivalentes, propiedades de las igualdades, ecuaciones con expresiones racionales, métodos de solución como uniformidad y transposición de términos, aplicaciones prácticas en escalas de temperatura y circuitos eléctricos, así como la capacidad para identificar cuando una ecuación no tiene solución o cuando una ecuación no es equivalente a la que la precede.
# Programa del curso: https://github.com/marco-canas/algebra_y_trigonometria/blob/main/1_plan_curso/1_programa_algebra_and_trigonometry.md
# Libro guía: [Álgebra y Trigonometría de Swokowski Edición 13](https://archive.org/details/algebra-y-trigonometria-con-geometria-analitica-13va-edicion-earl-w.-swokowski/page/n3/mode/2up)
#
# Secciones de Swokowski a evaluar:
#
# 2.1 Ecuaciones
# 2.2 Problemas de aplicación
# 2.3 Ecuaciones cuadráticas
# 2.4 Números complejos.
# 2.5 Otros tipos de ecuaciones.
# 2.6 Desigualdades.
# 2.7 Más sobre desigualdades.
#
# Temas a evaluar
#
# Ecuaciones lineales, Ecuaciones equivalentes, propiedades de las igualdades para obtener equiciones equivalentes, Ecuaciones con expresiones racionales, el método de uniformidad y el método de transposición de terminos para solución de ecuaciones lineales. Limitaciones del método de transposición de términos para resolver ecuaciones lineales, Ecuaciones con expresiones racionales que no tienen solución, Directrices para resolver ecuaciones que contengan expresiones racionales, Aplicaciones de las ecuaciones lineales y con expresiones racionales en escalas de temperatura y en circuitos eléctricos, Directrices para resolver problemas de aplicación de ecuaciones lineales y con expresiones racionales, .
#
# Saber determinar cuando no hay solución  o cuando la solución son todos los reales excepto uno de ellos:
#
# $$
# \frac{2x}{2x + 3} + \frac{6}{4x + 6} = 5
# $$
#
# $$
# \frac{2}{2x + 5} + \frac{3}{2x - 5} = \frac{10x + 5}{4x^{2} - 25}
# $$
#
#
# Saber determinar cuando una ecuación no es equivalente a la que la precede:
#
# $$ \begin{aligned} x^{2} - x - 2 & = x^{2} - 4 \\
# (x + 1)(x - 2) & = (x+2)(x -2) \\
# x + 1 & = x + 2 \\
# 1 & = 2
#  \end{aligned} $$
#
#
#
# $$ \begin{aligned}
# 5x + 6 & = 4x + 3 \\
# x^{2} + 5x + 6 & = x^{2} + 4x + 3 \\
# (x+2)(x+3) & = (x+1)(x+3) \\
# x + 2 & = x + 1 \\
# 2 & = 1
# \end{aligned} $$

# %% [markdown]
# Perfecto, Marco 🚀. Te diseño un **parcial de 7 puntos** (5 obligatorios y 2 opcionales), alineado con el **programa del curso** y con las secciones **2.1 a 2.7 de Swokowski**.
#
# ---
#
# # **Parcial de Álgebra y Trigonometría**
#
# **Basado en Swokowski, Secciones 2.1 – 2.7**
# **Duración:** 90 minutos
#
# 📌 **Instrucciones:**
#
# * Responda de manera clara y ordenada.
# * Desarrolle completamente los procedimientos.
# * Los primeros **5 problemas son obligatorios**.
# * De los problemas **6 y 7, resuelva únicamente UNO (opcional)**.
#
# ---
#
# ## **Parte Obligatoria (5 problemas)**
#
# ### **1. (Ecuaciones lineales – 2.1)**
#
# Resuelva la ecuación lineal y verifique la solución:
#
# $$
# 7x - 3(2x - 5) = 4x + 9
# $$
#
# ---
#
# ### **2. (Ecuaciones equivalentes – 2.1)**
#
# Determine si las siguientes transformaciones producen ecuaciones equivalentes. Justifique en cada paso.
#
# $$
# x^{2} - x - 2 = x^{2} - 4
# $$
#
# $$
# (x + 1)(x - 2) = (x + 2)(x - 2)
# $$
#
# $$
# x + 1 = x + 2
# $$
#
# ---
#
# ### **3. (Ecuaciones con expresiones racionales – 2.1 y 2.5)**
#
# Determine el conjunto solución de la ecuación:
#
# $$
# \frac{2x}{2x + 3} + \frac{6}{4x + 6} = 5
# $$
#
# Explique si la ecuación tiene **ninguna solución** o si existen valores de $x$ excluidos del dominio.
#
# ---
#
# ### **4. (Aplicación: Escalas de temperatura – 2.2)**
#
# La relación entre las escalas Celsius ($C$) y Fahrenheit ($F$) está dada por:
#
# $$
# F = \frac{9}{5}C + 32
# $$
#
# a) Determine la temperatura en grados Fahrenheit que corresponde a $C = 100^\circ$.
# b) Encuentre la temperatura en que las escalas Celsius y Fahrenheit coinciden.
#
# ---
#
# ### **5. (Desigualdades – 2.6 y 2.7)**
#
# Resuelva la desigualdad y represente la solución en la recta real:
#
# $$
# \frac{3x - 2}{x + 1} \leq 2
# $$
#
# ---
#
# ## **Parte Opcional (escoja UNO)**
#
# ### **6. (Aplicación en circuitos eléctricos – 2.2)**
#
# La resistencia total $R$ de dos resistencias $R_1$ y $R_2$ en paralelo está dada por:
#
# $$
# \frac{1}{R} = \frac{1}{R_1} + \frac{1}{R_2}
# $$
#
# Si $R_1 = 6 \, \Omega$ y $R_2 = 12 \, \Omega$, calcule la resistencia total $R$.
#
# ---
#
# ### **7. (Ecuaciones sin solución – 2.1 y 2.5)**
#
# Analice la ecuación:
#
# $$
# \frac{2}{2x + 5} + \frac{3}{2x - 5} = \frac{10x + 5}{4x^{2} - 25}
# $$
#
# a) Verifique si tiene solución.
# b) Explique si el dominio excluye algún valor de $x$.
#
# ---
#
# ✅ Con esto tienes un **parcial balanceado**, que cubre:
#
# * Procedimientos algebraicos (1, 3, 5).
# * Identificación de ecuaciones equivalentes (2, 7).
# * Aplicaciones prácticas (4, 6).
# * Análisis conceptual de ausencia de solución (3, 7).
#
# ---
#
# ¿Quieres que ahora te lo pase en **formato .docx con Python** (como los anteriores que me pediste) para que lo tengas listo para imprimir y entregar?

# %%
# Genero un archivo .docx con el parcial solicitado.
# El archivo usa representaciones de fracciones en "dos líneas" (numerador / barra / denominador)
# sin usar LaTeX. Usa fuente monoespaciada para las ecuaciones para mejorar la legibilidad.
# Si python-docx no está instalado en el entorno, el código instalará el paquete.
import sys
import os
from textwrap import fill

# Intento importar python-docx; si no está, lo instalo.
try:
    import docx
    from docx.shared import Pt
    from docx.oxml.ns import qn
except Exception as e:
    # instalar python-docx
    import subprocess, sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "python-docx"])
    import docx
    from docx.shared import Pt
    from docx.oxml.ns import qn

def stacked_fraction(numer: str, denom: str) -> str:
    """
    Devuelve una representación de fracción en 3 líneas:
    numerador
    barra (del largo máximo de numerador/denominador)
    denominador
    """
    # limpiamos espacios en los extremos
    numer = numer.strip()
    denom = denom.strip()
    width = max(len(numer), len(denom))
    bar = "―" * width  # barra larga
    return f"{numer}\n{bar}\n{denom}"

# Contenido del parcial (texto y ecuaciones con fracciones apiladas)
titulo = "Parcial de Álgebra y Trigonometría — Secciones 2.1–2.7 (Swokowski)\n\nDuración: 90 minutos\nPuntaje total: 7 puntos (5 obligatorios + 1 de 2 opcionales)\n\nInstrucciones:\n- Responda todo con procedimiento claro.\n- Los problemas 1 a 5 son obligatorios. Elija uno entre 6 y 7 (opcional).\n- Presente las operaciones y verifique las soluciones cuando corresponda.\n\n"

# Construyo las ecuaciones con fracciones apiladas
eq1 = "7x − 3(2x − 5) = 4x + 9"

# segunda (equivalencias) se deja en formato normal
eq2_lines = [
    "x² − x − 2 = x² − 4",
    "(x + 1)(x − 2) = (x + 2)(x − 2)",
    "x + 1 = x + 2",
    "1 = 2"
]

# Ecuación racional 1: (2x)/(2x+3) + 6/(4x+6) = 5
frac_a = stacked_fraction("2x", "2x + 3")
frac_b = stacked_fraction("6", "4x + 6")
eq_rational_1 = f"{frac_a}  +  {frac_b}  =  5"

# Ecuación racional 2: 2/(2x+5) + 3/(2x-5) = (10x+5)/(4x^2 - 25)
frac_c = stacked_fraction("2", "2x + 5")
frac_d = stacked_fraction("3", "2x − 5")
frac_e = stacked_fraction("10x + 5", "4x² − 25")
eq_rational_2 = f"{frac_c}  +  {frac_d}  =  {frac_e}"

# Desigualdad
ineq = stacked_fraction("3x − 2", "x + 1") + "  ≤  2"

# Aplicaciones
app_temp = "F = (9/5) C + 32"
app_circuit = "1/R = 1/R₁ + 1/R₂"

# Crear documento .docx
from docx import Document
from docx.shared import Pt
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

doc = Document()
# Estilo del título
p = doc.add_paragraph()
run = p.add_run("Parcial de Álgebra y Trigonometría — Secciones 2.1–2.7 (Swokowski)")
run.bold = True
run.font.size = Pt(14)
p.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

doc.add_paragraph("\nDuración: 90 minutos    Puntaje total: 7 puntos (5 obligatorios + 1 opcional)\n")

doc.add_paragraph("Instrucciones:")
doc.add_paragraph("- Responda todo con procedimiento claro.").runs[0].font.size = Pt(10)
doc.add_paragraph("- Los problemas 1 a 5 son obligatorios. Elija uno entre 6 y 7 (opcional).")
doc.add_paragraph("- Presente las operaciones y verifique las soluciones cuando corresponda.\n")

# Problema 1
doc.add_paragraph("1. (Ecuaciones lineales — 2.1) (1.0 pt)")
p = doc.add_paragraph()
p.add_run(eq1).font.name = 'Courier New'
p.runs[0].font.size = Pt(11)

# Problema 2
doc.add_paragraph("\n2. (Ecuaciones equivalentes — 2.1) (1.0 pt)")
for line in eq2_lines:
    p = doc.add_paragraph()
    r = p.add_run(line)
    r.font.name = 'Courier New'
    r.font.size = Pt(11)

# Problema 3 (racional)
doc.add_paragraph("\n3. (Ecuaciones con expresiones racionales — 2.1 y 2.5) (1.5 pt)")
p = doc.add_paragraph("Determine el conjunto solución de la ecuación y explique si tiene ninguna solución o si hay valores excluidos del dominio:")
p = doc.add_paragraph()
p_run = p.add_run(eq_rational_1)
p_run.font.name = 'Courier New'
p_run.font.size = Pt(11)

# Problema 4 (temperatura)
doc.add_paragraph("\n4. (Aplicación: Escalas de temperatura — 2.2) (1.0 pt)")
doc.add_paragraph("La relación entre Celsius (C) y Fahrenheit (F) es:")
p = doc.add_paragraph()
p.add_run("F = (9/5) C + 32").font.name = 'Courier New'
doc.add_paragraph("a) Determine F cuando C = 100.\nb) Encuentre la temperatura en que las escalas coinciden.")

# Problema 5 (desigualdad)
doc.add_paragraph("\n5. (Desigualdades — 2.6 y 2.7) (1.0 pt)")
doc.add_paragraph("Resuelva la desigualdad y dibuje la solución en la recta real:")
p = doc.add_paragraph()
p.add_run(ineq).font.name = 'Courier New'
p.runs[0].font.size = Pt(11)

# Opcionales
doc.add_paragraph("\nParte opcional — escoja UNO (resolver solo uno) (1.5 pt)")

# Problema 6 (circuito)
doc.add_paragraph("\n6. (Aplicación en circuitos eléctricos — 2.2)")
doc.add_paragraph("La resistencia total R de dos resistencias en paralelo: 1/R = 1/R₁ + 1/R₂")
doc.add_paragraph("Si R₁ = 6 Ω y R₂ = 12 Ω, calcule R.")

# Problema 7 (racional 2)
doc.add_paragraph("\n7. (Ecuaciones sin solución y dominio — 2.1 y 2.5)")
doc.add_paragraph("Analice la ecuación:")
p = doc.add_paragraph()
p.add_run(eq_rational_2).font.name = 'Courier New'
p.runs[0].font.size = Pt(11)
doc.add_paragraph("a) Verifique si tiene solución.\nb) Explique si el dominio excluye algún valor de x.")

# Footer / referencias
doc.add_paragraph("\nReferencias: Programa del curso y Swokowski, Secciones 2.1–2.7.")

# Guardar archivo
out_path = r"C:\Users\marco\Downloads\parcial_algebra_trigonometria.docx"
doc.save(out_path)

out_path
# Out:
# 'C:\\Users\\marco\\Downloads\\parcial_algebra_trigonometria.docx'
