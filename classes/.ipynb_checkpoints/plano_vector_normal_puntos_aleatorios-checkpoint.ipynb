# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/algebra/blob/main/classes/plano_vector_normal_puntos_aleatorios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # Cómo trazar un plano y diez puntos aleatorios alineados perpendicularmente al plano dado.

# %% [markdown]
# Consideremos el plano de ecuación
#
# $$ ax + by + cz = 0 $$

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
a,b,c = 1,2,3

# %%
n = np.array([a,b,c]) # Vector normal al plano

# %%
import numpy as np
import matplotlib.pyplot as plt

from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D

a,b,c = 1,2,3
point  = np.array([1, 2, 3])
normal = np.array([a, b, c])

point2 = np.array([10, 50, 50])

# a plane is a*x+b*y+c*z+d=0
# [a,b,c] is the normal. Thus, we have to calculate
# d and we're set
d = -point.dot(normal)

# create x,y
xx, yy = np.meshgrid(range(10), range(10))

# calculate corresponding z
z = (-normal[0] * xx - normal[1] * yy - d) * 1. /normal[2]

# plot the surface
plt3d = plt.figure().gca(projection='3d')
plt3d.plot_surface(xx, yy, z, alpha=0.2)


#and i would like to plot this point : 
for t in np.random.rand(10):
    plt3d.scatter(t*normal[0] , t*normal[1] , t*normal[2],  color='red')


plt.show()
# Out:
# C:\Users\Marco\AppData\Local\Temp\ipykernel_2068\2079630091.py:25: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   plt3d = plt.figure().gca(projection='3d')

# %%
t = np.random.rand(10)
# Out:
# array([0.18351061, 0.57348039, 0.67695856, 0.45475868, 0.52308424,
#        0.46619952, 0.59308347, 0.96117216, 0.15487328, 0.27514744])
