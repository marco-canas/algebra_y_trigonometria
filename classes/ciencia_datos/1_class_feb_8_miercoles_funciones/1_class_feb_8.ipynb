# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/algebra/blob/main/classes/ciencia_datos/1_class/1_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Descripción de la lista de repreducción de apoyo al aprendizaje](https://www.youtube.com/watch?v=fNDJ8Dkz2Mo)

# %% [markdown]
# ### [Aula invertida]()

# %% [markdown]
# ## Objetivo de aprendizaje

# %% [markdown]
# * la tuplas en python
# * cómo definir funciones
# * La documentación de las funciones en Python
# * el módulo pyplot de la librería matplitlib
# * el módulo animation de la librería matplotlib

# %% [markdown]
# ### [¿Cómo liderar?](https://asana.com/es/resources/qualities-of-a-leader)
#
# Además de trabajar arduamente, los líderes tienen una chispa que genera inspiración y motiva al equipo.
# Un buen líder es consciente de sí mismo, se comunica eficazmente, delega trabajo, fomenta el pensamiento estratégico y motiva a los miembros del equipo para dar lo mejor. En este artículo, descubre qué es ser un líder, las 15 cualidades de líder más importantes y ejemplos de cómo ser un buen líder para que tú también puedas inspirar a quienes te rodean.

# %% [markdown]
# #  Presaberes

# %% [markdown]
# * ¿Qué es una función?
#
# es una máquina. Ejemplo: $y = 2x = f(x)$

# %% [markdown]
# ## Representar a las funciones de manera tabular

# %% [markdown]
# |x|y|
# |-|-|
# |1|800|
# |2|1600|
# |3|2400|
#
# Esta es la representación tabular de una función: La función que para el n´mero de huevos nos entrega el valor a pagar.

# %% [markdown]
# ## Representación bidimensional o en plano cartesiano de la función

# %%
import matplotlib.pyplot as plt 

lo_que_entra=[1,2,3]
lo_que_sale=[800,1600,2400]

plt.scatter(lo_que_entra,lo_que_sale)

plt.plot(lo_que_entra,lo_que_sale)

plt.xlabel('número de huevos')
plt.ylabel('el valor de los huevos')
# Out:
# Text(0, 0.5, 'el valor de los huevos')

# %% [markdown]
# ## Interpretaciones del gráfico
#
# 1. La relación entre número de huevos y precio de los mismos es creciente y lineal.
# 2. a más huevos compramos, más es el valor a pagar.

# %% [markdown]
# # Tareas para fijar conceptos y adquirir habilidades

# %% [markdown]
# 1. realice una representación tabular de la función que duplica ($y = f(x) = 2x$).
# 2. Realice el gráfico de dispersión y el gráfico de líneas de la función $y = f(x) = 2x$.

# %% [markdown]
# ## Evaluacion (Ejercicios tipo parcial o tipo quiz)

# %% [markdown]
# ## Referentes
#
# * Larson:  https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES71ChFeO9ZDhW3TwC5Ijk8B3FNdovvzB9vT_ArJLa_Agg?e=a6TF5R
#
#
# * Getting Started with Plotly in Python : https://plotly.com/python/getting-started/

# %% [markdown]
# # [Apéndice sobre Plotly](https://plotly.com/python/getting-started/)

# %% [markdown]
# ## Graficar con Plotly
