# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/algebra_y_trigonometria/blob/main/classes/1_IntroductionPythonJupyterNotebooks/1_class_python_for_math/1_intro_python_languaje.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/algebra_y_trigonometria/blob/main/classes/1_IntroductionPythonJupyterNotebooks/1_class_python_for_math/1_intro_python_languaje.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %%
# codigo del recurso de estudio para la funcion senoidal 

import numpy as np # Genera la progresión aritmética para el dominio de graficación. 
import matplotlib.pyplot as plt # Grafica la función y = y(x) en el dominio de graficación.
from ipywidgets import interact # Interactividad o deslizados para mover los parámetros A, B, C, y D 
#definir dominio  
a, b = 0, 4*np.pi
# definir conjunto de llegada
c, d = -6, 6
@interact(A=(1, 5), B = (1, 5), C = (0, 2*np.pi, 0.1), D = (-2, 2))   

def graficar_seno(A=1, B=1, C=0, D=0):
    x = np.linspace(0, 4*np.pi, 200) # crea una secuencia de 201 números entre 0 y 4π 
    y = A * np.sin(B*x + C) + D # 
    plt.figure(figsize=(8, 3)) # genera un lienzo o figura de 10 x 4 pulgadas 
    plt.title('Exploración a las gráficas de $y = A sen(Bx + C) + D$')
    plt.axis([a, b, c, d]) # defines el rectangulo de visualización de la gráfica
    plt.axhline(y = 0, color = 'blue')
    plt.axvline(x = 0)
    plt.xticks(np.arange(a,b+np.pi/2, np.pi/2), ['0', 'pi/2', 'pi', '3pi/2', '2pi', '5pi/2', '6pi/2', '7pi/2', '4pi'] ) # metrizar el eje horizontal o escalar los ejes. 
    plt.yticks(np.arange(c,d+1)) # metrizar el eje vertical 
    plt.plot(x, y, label=f"${A}\\cdot\\sin({B}x + {C:.1f}) + {D}$", color = 'red') # Hace gráficos de líneas 
    plt.legend('Exploración de las gráficas de $y = A \cdot \sin(Bx + C) + D$')
    plt.grid()
    plt.savefig(r"C:\Users\marco\Downloads\exploracion_graficas_y_A_sin.jpg")
    plt.show()
# Out:
# interactive(children=(IntSlider(value=1, description='A', max=5, min=1), IntSlider(value=1, description='B', m…

# %% [markdown]
# ### Guía para Enseñar el Uso del Recurso Interactivo en Python
#
# #### **Objetivo:**
# Enseñar a los estudiantes a utilizar el código interactivo para explorar cómo los parámetros **A**, **B**, **C** y **D** afectan la gráfica de la función sinusoidal:
# $$ y = A \cdot \sin(Bx + C) + D $$
# Los estudiantes aprenderán a diferenciar:
# - **Amplitud (A)**: Altura de la onda.
# - **Periodo (B)**: Longitud de un ciclo completo.
# - **Fase (C)**: Desplazamiento horizontal.
# - **Sesgo (D)**: Desplazamiento vertical.
#
# ---
#
# ### **1. Requisitos Previos**
# Asegúrate de que los estudiantes tengan instalado:
# - **Python** (versión 3.6 o superior).
# - Las bibliotecas: `numpy`, `matplotlib`, `ipywidgets`.
#   ```bash
#   pip install numpy matplotlib ipywidgets
#   ```
# - **Jupyter Notebook** (opcional, pero recomendado para interactividad).
#   ```bash
#   pip install notebook
#   ```
#
# ---
#
# ### **2. Ejecución del Código**
# #### **Opción A: Desde Terminal (sin Jupyter Notebook)**
# 1. Guarda el código en un archivo, por ejemplo: `seno_interactivo.py`.
# 2. Ejecútalo desde la terminal con:
#    ```bash
#    python seno_interactivo.py
#    ```
#    **Nota:** Si usas VS Code o PyCharm, abre el archivo y ejecútalo directamente.
#
# #### **Opción B: Con Jupyter Notebook (recomendado para interactividad)**
# 1. Inicia Jupyter:
#    ```bash
#    jupyter notebook
#    ```
# 2. Crea un nuevo notebook y pega el código en una celda.
# 3. Ejecuta la celda para ver los controles deslizantes interactivos.
#
# ---
#
# ### **3. Explicación de los Parámetros**
# **Demuestra cómo cada parámetro afecta la gráfica:**
#
# 1. **Amplitud (A):**
#    - **Rango:** 1 a 5.
#    - **Efecto:** Controla la altura de la onda.
#    - **Ejemplo:**
#      - `A=1`: Oscila entre -1 y 1.
#      - `A=3`: Oscila entre -3 y 3.
#
# 2. **Periodo (B):**
#    - **Rango:** 1 a 5.
#    - **Efecto:** Determina cuánto tarda un ciclo completo.
#      - Fórmula: `Periodo = 2π / B`.
#    - **Ejemplo:**
#      - `B=1`: Periodo = 2π.
#      - `B=2`: Periodo = π (ciclos más cortos).
#
# 3. **Fase (C):**
#    - **Rango:** 0 a 2π.
#    - **Efecto:** Desplaza la gráfica horizontalmente.
#    - **Ejemplo:**
#      - `C=0`: Sin desplazamiento.
#      - `C=π/2`: Desplazamiento a la izquierda en π/2.
#
# 4. **Sesgo (D):**
#    - **Rango:** -2 a 2.
#    - **Efecto:** Desplaza la gráfica verticalmente.
#    - **Ejemplo:**
#      - `D=0`: Centrada en y=0.
#      - `D=1.5`: Sube toda la gráfica 1.5 unidades.
#
# ---
#
# ### **4. Actividad Práctica**
# **Pide a los estudiantes que:**
# 1. Fijen `B=1`, `C=0`, `D=0` y varíen **A**. Observen cómo cambia la amplitud.
# 2. Fijen `A=1`, `C=0`, `D=0` y varíen **B**. Calculen el periodo teórico y compárenlo con la gráfica.
# 3. Fijen `A=1`, `B=1`, `D=0` y varíen **C**. Identifiquen el desplazamiento horizontal.
# 4. Fijen todos los parámetros excepto **D** y observen el desplazamiento vertical.
#
# ---
#
# ### **5. Preguntas de Reflexión**
# - ¿Cómo se relaciona **B** con la frecuencia de la onda?
# - ¿Por qué **C** se mide en radianes?
# - Si `D=2` y `A=3`, ¿entre qué valores oscila la función?
#
# ---
#
# ### **6. Notas Adicionales**
# - **Guardar gráficas:** El código incluye `plt.savefig()` para guardar imágenes (útil para informes).
# - **Personalización:** Los estudiantes pueden modificar el dominio (`a, b`) o el rango de los parámetros.
#
# **¡Con esto, los estudiantes dominarán los conceptos clave de las funciones sinusoidales de manera visual e interactiva!** 🌊📊
