# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/algebra_y_trigonometria/blob/main/3_planeacion/2_classes/3_unidad_2_ecuaciones_e_inecuaciones/2_6_desigualdades/2_6_desigualdades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/marco-canas/algebra_y_trigonometria/blob/main/3_planeacion/2_classes/3_unidad_2_ecuaciones_e_inecuaciones/2_6_desigualdades/2_6_desigualdades.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# # generación del QR para el cuaderno de esta clase
#
# Aquí tienes una función de Python que genera un código QR a partir de una URL y lo muestra en un cuaderno Jupyter:

# %%
import qrcode
from IPython.display import display

def generar_qr_notebook(url):
    """
    Genera un código QR para una URL y lo muestra en un cuaderno Jupyter.
    
    Parámetros:
    url (str): La URL para la cual se generará el código QR.
    
    Retorna:
    None (pero muestra el código QR en el notebook)
    """
    # Crear el objeto QR
    qr = qrcode.QRCode(
        version=1,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=10,
        border=4,
    )
    
    # Añadir la URL al código QR
    qr.add_data(url)
    qr.make(fit=True)
    
    # Crear la imagen del QR
    img = qr.make_image(fill_color="black", back_color="white")
    
    # Mostrar la imagen en el notebook
    display(img)

# %%
url = 'https://colab.research.google.com/github/marco-canas/algebra_y_trigonometria/blob/main/3_planeacion/2_classes/3_unidad_2_ecuaciones_e_inecuaciones/2_6_desigualdades/2_6_desigualdades.ipynb'
generar_qr_notebook(url)

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ### [Vínculo al programa del curso Algebra_and_trigonometry:  ](https://github.com/marco-canas/algebra_y_trigonometria/blob/main/0_programa_curso/programa_algebra_and_trigonometry.md)
# Código del curso de Álgebra y Trigonometría: 303001

# %% [markdown]
# Un reconocimiento a mis estudiantes que han construido conmigo este saber pedagógico:
#
# <img src = 'https://github.com/marco-canas/algebra_y_trigonometria/blob/main/7_images/asesoria_2025-09-20_1.jpg?raw=true' width = 600>

# %% [markdown]
# Reconocimiento a las profesoras destacadas en enseñanza de la matemática en Colombia

# %%
import pandas as pd
import numpy as np

# Cargar la lista de estudiantes desde el archivo CSV
path = 'C:/Users/marco/Documentos/docencia/groups_list/algebra_and_trigonometry.xlsx'
df = pd.read_excel(path)
df.index = np.arange(1, len(df) + 1)
df.head(19)
# Out:
#         Cedula                             Nombre  \
# 1   1038648096            ACEVEDO BELEÑO SANTIAGO
# 2   1038111190            CANOLE PEÑATE SEBASTIAN
# 3   1038113597            CORREA RESTREPO NICOLAS
# 4   1038108190            HERNANDEZ GOMEZ MICHAEL
# 5   1038648760   MARIN VILLARREAL PABLO ALEJANDRO
# 6   1193401041  MARTINEZ MANJARREZ DANIELA ESTHER
# 7   1038108720                MEJIA GUZMAN SAMUEL
# 8   1038647828    NIEBLES BARRERA ALEXANDER ISAAC
# 9   1045426138      OQUENDO MONA CRISTIAN GABRIEL
# 10  1038136953        PATINO GIL CHRISTIAN FELIPE
# 11  1032250901                PINO VERGARA LIZETH
# 12  1038092717             RIVERA GUZMAN CRISTIAN
# 13  1038110693        ROMERO CALDERA JUAN ESTEBAN
# 14  1038647713       SÁNCHEZ HERRERA JUAN ESTEVAN
# 15  1063359347       SANCHEZ PACHECO MOISES DAVID
# 16  1066600819  TIRADO CHAVARRIA WILFRAN DE JESUS
# 17  1038136995      VERGARA ACEVEDO SARA CRISTINA
# 18  1007452831           VILORIA SIERRA ALEXANDER
# ...

# %% [markdown]
# # Estructura general para todas las clases

# %% [markdown]
# Dame, por favor, un diseño de clase, con el enfoque: "Aula Invertida, STEAMS, de Aprendizaje Basado en Problemas y Proyectos (ABPP) y de Teoría de Registros de Representación Semiótica (TRRS) de Duval" sobre: "Desigualdades e inecuaciones: un enfoque para la clase de álgebra y trigonometría según el programa de curso: https://github.com/marco-canas/algebra_y_trigonometria/blob/main/0_programa_curso/1_programa_algebra_and_trigonometry.md; y para el curso de Geometría Euclidiana, analítica y vectorial.", siguiendo la estructura:
#
#
#
# 1. Título de la clase
#
# 2. Objetivo de aprendizaje que incluyan los indicadores del logro de estos objetivos.
#
# 3. Un mapa conceptual que resuma la clase elaborado en Graphviz de python con nodos y edges de diferentes formas, colores y rellenos y renderizado en la siguiente ubicación: `"C:\Users\marco\Downloads"`.  No olvides el parámetro `view = True` para el método `render()` de Graphviz. Para este mapa controla las superposiciones de los nodos con: graph [overlap=false]; // Elimina superposiciones (puede aumentar el espacio)
# graph [overlap="scalexy"]; // Escala el gráfico para evitar overlaps
# graph [overlap="compress"]; // Comprime el grafo sin overlaps
#
# 4. Elementos históricos y epistemológicos relevantes para la clase, pero narrados como una historieta al estilo de un cuentero antioqueño en Colombia. Incluye imágenes de los protagonistas históricos de esta clase.
#
# 5. Contenido de la clase:  Muestra el siguiente contenido de la clase:
#    - Inecuaciones lineales.
#    - Inecuaciones continuas.
#    - Ineciaciuones Racionales.
#    - Inecuaciones cuadráticas.
#    Pero mostrando como resolver cada uno de estos tipos de inecuaciones a través de:
#      1. [Solución algebraica manuscrita](https://www.youtube.com/watch?v=YgfJO8m_iTQ).
#      2. Solución algebraica en lenguaje latex
#      3. Solución con calculo simbólico con SymPy.
#      4. Solución tabular de la ecuación (Una columna por función lado de la ecuación)
#      5. Solución Gráfica con Matplotlib
#      6. Solución Gráfica con GeoGebra.
#      7. Solución gráfica con Wolframe.
#
# 6. Actividades de aprendizaje:
#
# 7. Incluye una canción o un poema que ayude a interiorizar y fijar los conceptos asociados a esta clase.
#
# 8.  Tarea o actividades de ejercitación y fijación. Incluye 20 ejercicios de tarea en las que los estudiantes empiecen con la descripción geométrica del algoritmo, luego la descripción verbal y secuencial del algoritmo, después la implementación en lenguaje python editado a través de la terminal powershell de su computador y finalmente con el cálculo a mano y en su cuaderno. Crea una función de usuario de Python que asigne esta tareas a cada uno de los estudiantes matriculados en este curso tomando la ubicación de los estudiantes dada en este prompt.
#
# 9. Evaluación incluyendo 20 proyectos, un ejemplo de quiz (con tres items) y un ejemplo de parcial (con 5 items). Incluye evaluaciones en las que los estudiantes empiecen con la descripción geométrica del algoritmo, luego la descripción verbal y secuencial del algoritmo, después la implementación en lenguaje python editado a través de la terminal powershell de su computador, y finalmente con el cálculo algebraico y numérico a mano y en su cuaderno.
#
# 10. Diseño de actividad de retroalimentación.
#
# 11. Dame un vocabulario y frases del idioma inglés asociadas a esta clase.
#
# 12. Incluye apéndice para la clase sobre desarrollo de habilidades para trabajar en equipo y de asertividad y empatía para relacionarnos. También elementos de la inteligencia emocional para presentar pruebas sin temor y sin realizar fraude en ellas.
#
# 13. Incluye 10 referentes en didáctica de la matemática que estén de acuerdo a la propuesta didáctica de esta clase. Adiciona a estos referentes a Raymond Duval (Representaciones y cambios de representación para la adquisición de conceptos matemáticos) y a [Jeannette Wing](https://es.wikipedia.org/wiki/Jeannette_Wing) (Desarrollo del pensamiento computacional). Déjame todos estos referentes ordenados de acuerdo a las normas APA. Al crear la clase, introduce las citas de estos autores en el texto de la clase.
#
#
# Pero  que este diseño sea para que el estudiante pueda aprender experimentando en cuadernos Jupyter con funciones de usuario y animaciones y visualizaciones en python.
#
# En particular utiliza para el diseño de clase a Numpy, Pandas, SymPy, Matplotlib.pyplot, Seaborn, Plotly, ipywidgets, matplotlib.animation, TensorFlow, Keras y Jupyter Notebook.
#
# Cada vez que utilices `matplotlib.animacion` no olvides incluir el uso de `IPython. display` para la rederización de estas animaciones a través de Jupyter Notebook. No olvides darme los diseños de clase con las ecuaciones matemáticas delimitadas con signo de dolar $ para que VS Code si me renderize estas expresiones del lenguaje latex. Cuando vallas a utilizar ipywidgets ten en cuenta la siguiente importación inicial para garantizar que la visualización interactiva si se renderize en VS Code:
#
#
# Ubicación del diseño de investigación IAE: https://github.com/marco-canas/algebra_y_trigonometria/blob/main/1_plan_curso/0_dise%C3%B1o_invts_IAE.md
#
# Ubicación del programa del curso: [aquí](un enfoque para la clase de álgebra y trigonometría según el programa de curso: https://github.com/marco-canas/algebra_y_trigonometria/blob/main/0_programa_curso/1_programa_algebra_and_trigonometry.md)
#
# Ubicación del texto Guía: https://archive.org/details/algebra-y-trigonometria-con-geometria-analitica-13va-edicion-earl-w.-swokowski/page/n3/mode/2up
#
# Ubicación de la lista de estudiantes matriculados: [Aquí](https://github.com/marco-canas/groups_list/blob/main/vector_geometry_and_linear_algebra.xlsx)

# %% [markdown]
# Excelente — te entrego un **diseño de clase completo** (en español) con el enfoque solicitado (Aula Invertida, STEAMS, ABPP, TRRS de Duval), pensado para que el estudiante aprenda **experimentando en Jupyter** usando Numpy, Pandas, SymPy, Matplotlib, Seaborn, Plotly, ipywidgets, matplotlib.animation, TensorFlow/Keras (solo para ejemplos muy puntuales si aplican) y con las instrucciones para renderizar el mapa conceptual con Graphviz en tu ruta `"C:\Users\marco\Downloads"`. Incluiré código listo para Jupyter / VS Code (expresiones con `$...$` para que VS Code renderice LaTeX) y ejemplos de funciones de usuario para asignar tareas usando la lista de estudiantes en el repositorio que indicaste. También insertaré las citas de Duval y Wing en lugares relevantes y te doy referencias (APA) al final.
#
# Importante: he comprobado y usado las páginas y recursos de tu repositorio de diseño IAE, la lista de estudiantes y la guía/ texto referenciado y referencias para Duval y Wing para apoyar el diseño. ([GitHub][1])
#
# ---
#
# # 1. Título de la clase
#
# **Desigualdades e inecuaciones: representación, resolución y visualización multimodal (álgebra y trigonometría / geometría)**
#
# ---
#
# # 2. Objetivo de aprendizaje (con indicadores de logro)
#
# **Objetivo general**
# El estudiante será capaz de analizar, resolver y representar inecuaciones e inecuaciones compuestas (lineales, racionales, cuadráticas y continuas) usando registros semióticos múltiples (verbales, algebraicos, gráficos, simbólicos, numéricos) y herramientas computacionales (SymPy, NumPy, Matplotlib, GeoGebra), integrando la competencia de comunicar y justificar resultados matemáticos.
#
# **Indicadores de logro**
#
# 1. Resolver algebraicamente inecuaciones lineales, racionales y cuadráticas y justificar cada paso con lenguaje matemático formal.
# 2. Expresar la solución de una inecuación en forma de intervalo y en representación gráfica (recta numérica y gráfica en plano).
# 3. Convertir y verificar una inecuación mediante: tratamiento simbólico (SymPy), tabla de signos (tabla tabular), y trazado gráfico (Matplotlib / GeoGebra).
# 4. Diseñar una breve presentación (2–3 minutos) que muestre la conversión entre representaciones (gráfica → algebraica → simbólica) y explique por qué la conversión preserva la solución (aplicando la TRRS de Duval). (Criterio: coherencia entre registros). ([pat-thompson.net][2])
#
# ---
#
# # 3. Mapa conceptual (Graphviz en Python)
#
# Te dejo un **snippet** listo para Jupyter / VS Code que crea un archivo `inecuaciones_mapa` y lo renderiza en la ubicación que indicas (Windows). Este grafo usa `overlap` y opciones para evitar superposición y con distintos colores/forma para nodos.
#
# ```python
# # Requiere: graphviz (pip install graphviz) y que Graphviz esté instalado en el sistema (dot)
# from graphviz import Digraph
#
# dot = Digraph('Inecuaciones', format='pdf')  # cambia formato si quieres png
# dot.attr(rankdir='LR', fontsize='12')
# # control de overlaps
# dot.attr('graph', overlap='false')
# dot.attr('graph', overlap='scalexy')
# dot.attr('graph', overlap='compress')
#
# # Nodos principales (formas, colores, estilo)
# dot.node('A', 'Inecuaciones', shape='ellipse', style='filled', fillcolor='#e6f2ff')
# dot.node('B', 'Lineales', shape='box', style='filled', fillcolor='#fff2cc')
# dot.node('C', 'Cuadráticas', shape='box', style='filled', fillcolor='#ffd9e6')
# dot.node('D', 'Racionales', shape='box', style='filled', fillcolor='#e6ffe6')
# dot.node('E', 'Continuas/No-lineales', shape='box', style='filled', fillcolor='#ece6ff')
#
# # Registros semióticos (Duval)
# dot.node('R1', 'Registro: Verbal', shape='note', fillcolor='#fff5e6', style='filled')
# dot.node('R2', 'Registro: Algebraico', shape='note', fillcolor='#f5f5f5', style='filled')
# dot.node('R3', 'Registro: Gráfico', shape='note', fillcolor='#e6f7ff', style='filled')
# dot.node('R4', 'Registro: Simbólico (SymPy)', shape='note', fillcolor='#f0e6ff', style='filled')
# dot.node('R5', 'Registro: Tabular', shape='note', fillcolor='#e6ffe6', style='filled')
#
# # Herramientas
# dot.node('T1', 'Numpy / Pandas', shape='oval', style='filled', fillcolor='#f2f2f2')
# dot.node('T2', 'SymPy', shape='oval', style='filled', fillcolor='#fff0f0')
# dot.node('T3', 'Matplotlib / Plotly', shape='oval', style='filled', fillcolor='#e6f7ff')
# dot.node('T4', 'GeoGebra', shape='oval', style='filled', fillcolor='#fffbe6')
#
# # Edges
# dot.edges([('A','B'),('A','C'),('A','D'),('A','E')])
# dot.edges([('B','R2'),('B','R3'),('B','R4'),('B','R5')])
# dot.edges([('C','R2'),('C','R3'),('C','R4'),('C','R5')])
# dot.edge('R4','T2', label='cálculo simbólico')
# dot.edge('R3','T3', label='visualización')
# dot.edge('R5','T1', label='tabulación')
# dot.edge('R2','T1', label='arrays')
# dot.edge('A','R1', style='dashed')
#
# # render en la ruta que pediste
# output_path = r"C:\Users\marco\Downloads\inecuaciones_mapa"
# dot.render(filename=output_path, view=True)
# ```
#
# > Nota: para que `view=True` funcione en Windows necesitas que la extensión resulte en un archivo legible (por ej. `pdf`) y que Graphviz `dot` esté en el PATH. El comando `dot` debe estar instalado (Graphviz system package).
#
# ---
#
# # 4. Elementos históricos y epistemológicos — **historieta al estilo cuentero antioqueño** (con imágenes)
#
# A continuación una historieta en forma narrativa breve — estilo cuentero antioqueño — con **protagonistas históricos** vinculados a la geometría y el álgebra (Euclides, René Descartes) y la idea moderna de representaciones (Raymond Duval). Incluiré enlaces a imágenes representativas para usar en material visual.
#
# **Historieta — “La charla de la plaza”**
#
# > Era en la plaza del pueblo, junto a la iglesia, cuando don Euclides —un sabio de mirada serena— empezó a trazar en la tierra un triángulo perfecto con una varita de guadua. “Muchachos,” dijo, “la geometría es la razón que trae orden al mundo.”
# >
# > Por ahí llegó el juvenil Descartes, con un cuaderno debajo del brazo. “Pero compadre Euclides,” replicó, “si ponemos números junto a la geometría, podemos mover figuras con el lenguaje del álgebra.” Y así nació la plática entre rectas y ecuaciones.
# >
# > Cuando la gente escuchó la discusión, vino Raymond Duval con su sombrero de profesor y explicó: “Ché, lo importante no es sólo la figura ni sólo la ecuación; es poder *cambiar de registro*: escribir, dibujar, simbolizar y traducir unos en otros. Eso es lo que hace pensar matemáticamente.”
# >
# > Y la plaza se llenó de estudiantes que tomaron cuaderno, tablero y calculadora, aprendiendo a convertir una gráfica en una expresión y una expresión en una historia. Cada quien contó la inecuación como quien cuenta un cuento: con palabras, con figuras y con símbolos que se entendieran en cualquier lengua.
#
# **Imágenes (propuestas para material visual)**
#
# * Euclides — representaciones históricas (imagen para diapositiva).
# * René Descartes — retratos clásicos.
# * Raymond Duval — trabajos y textos sobre registros semióticos (usar PDF/portada y foto institucional si disponible). ([pat-thompson.net][2])
#
# > Nota sobre imágenes: para uso en presentaciones, revisa licencias y atribuciones de cada imagen antes de publicarlas.
#
# ---
#
# # 5. Contenido de la clase: tipos de inecuaciones + procedimientos multimodales
#
# Para cada tipo mostraré **7** maneras de resolver: 1) solución manuscrita, 2) LaTeX, 3) SymPy, 4) tabla tabular, 5) Matplotlib, 6) GeoGebra (instrucción breve), 7) Wolfram (hint). Cada apartado tendrá ejemplo concreto.
#
# > Importante: en las fórmulas uso `$...$` para LaTeX (VS Code). Para todos los bloques de SymPy escribiré código listo para Jupyter.
#
# ---
#
# ## 5.1 Inecuaciones lineales
#
# **Ejemplo:** resolver \$2x - 5 > 1\$
#
# 1. **Manuscrito:**
#    \$2x - 5 > 1 \Rightarrow 2x > 6 \Rightarrow x > 3\$.
#
# 2. **LaTeX (listo):**
#    `$2x - 5 > 1 \implies 2x > 6 \implies x > 3$`
#
# 3. **SymPy:**
#
# ```python
# import sympy as sp
# x = sp.symbols('x', real=True)
# sol = sp.solve_univariate_inequality(2*x - 5 > 1, x)
# sol
# # devuelve Interval (3, oo)
# ```
#
# 4. **Solución tabular (tabla de signos)** — una columna para cada término:
#    Construyes columnas: `2x`, `-5`, `2x-5`, comparas con `1`. En práctica se resta 1: `2x-6` → signo positivo para \$x>3\$.
#
# 5. **Gráfica con Matplotlib:**
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# xs = np.linspace(-1, 6, 400)
# ys = 2*xs - 5
# plt.axhline(1, color='k', linewidth=0.8)
# plt.plot(xs, ys, label='2x-5')
# plt.fill_between(xs, ys, 1, where=(ys>1), alpha=0.2)
# plt.axvline(3, color='red', linestyle='--', label='x=3')
# plt.legend()
# plt.show()
# ```
#
# 6. **GeoGebra:**
#
# * Entrada: `y = 2x-5` y `y = 1`. Visualiza región donde \$2x-5>1\$. (Instrucción: usar la herramienta “Intersección” y sombreado de desigualdad).
#
# 7. **Wolfram:** escribir `Solve[2 x - 5 > 1, x]` en WolframAlpha o Mathematica.
#
# ---
#
# ## 5.2 Inecuaciones cuadráticas
#
# **Ejemplo:** \$x^2 - 5x + 6 \le 0\$
#
# 1. **Manuscrito:** factoriza: \$(x-2)(x-3) \le 0\$ → solución \$x \in \[2,3]\$ (intervalo entre raíces).
#
# 2. **LaTeX:** `$x^2 - 5x + 6 \le 0 \Rightarrow (x-2)(x-3)\le 0 \Rightarrow x\in[2,3]$`
#
# 3. **SymPy:**
#
# ```python
# x = sp.symbols('x', real=True)
# sp.solve_univariate_inequality(x**2 - 5*x + 6 <= 0, x)
# # Interval(2, 3)
# ```
#
# 4. **Tabla tabular:** tres columnas: `(x-2)`, `(x-3)`, producto; signos en intervalo `(-inf,2), (2,3), (3,inf)`.
#
# 5. **Gráfica Matplotlib:**
#
# ```python
# xs = np.linspace(0,5,300)
# ys = xs**2 - 5*xs + 6
# plt.plot(xs, ys)
# plt.fill_between(xs, ys, 0, where=(ys<=0), alpha=0.2)
# plt.axhline(0, color='k')
# plt.show()
# ```
#
# 6. **GeoGebra:** `y = x^2 - 5x + 6`, usar región `y <= 0` para sombrear.
#
# 7. **Wolfram:** `Solve[x^2 - 5 x + 6 <=0, x]` → `[2,3]`.
#
# ---
#
# ## 5.3 Inecuaciones racionales
#
# **Ejemplo:** \$\frac{x-1}{x+2} > 0\$
#
# 1. **Manuscrito:** Identificar ceros y polos: cero en \$x=1\$, polo en \$x=-2\$. Construir tabla de signos → solución \$x \in (-\infty, -2) \cup (1, \infty)\$ (verificando intervalos).
#
# 2. **LaTeX:** `$\frac{x-1}{x+2} > 0 \Rightarrow x \in (-\infty,-2) \cup (1,\infty)$ (excluir -2)$`
#
# 3. **SymPy:**
#
# ```python
# sp.solve_univariate_inequality((x-1)/(x+2) > 0, x)
# ```
#
# 4. **Tabla tabular:** columnas `x-1`, `x+2`, razón y signo en intervalos `(-inf, -2), (-2,1), (1,inf)`.
#
# 5. **Matplotlib:** plot de la función con regiones resaltadas y evitar punto en `x=-2`.
#
# 6. **GeoGebra:** `f(x) = (x-1)/(x+2)` y usar herramienta desigualdad `f(x)>0`.
#
# 7. **Wolfram:** `Solve[(x-1)/(x+2)>0, x]`.
#
# ---
#
# ## 5.4 Inecuaciones “continuas” / trascendentes (ejemplo con trigonometría)
#
# **Ejemplo:** \$\sin x > 0\$ en $\[0, 2\pi]\$
#
# 1. **Manuscrito:** solución \$x \in (0, \pi)\$.
#
# 2. **LaTeX:** `$\sin x > 0 \quad \Rightarrow \quad x \in (0,\pi) + 2k\pi,\; k\in\mathbb Z$`
#
# 3. **SymPy:**
#
# ```python
# sp.solveset(sp.sin(x) > 0, x, domain=sp.Interval(0, 2*sp.pi))
# ```
#
# 4. **Tabla tabular:** evaluar signos por intervalos `[0, π/2), (π/2, π), ...`
#
# 5. **Matplotlib:** trazar `sin(x)` y sombrear regiones positivas.
#
# 6. **GeoGebra:** `y=sin(x)` y sombrear intervalo.
#
# 7. **Wolfram:** `Reduce[Sin[x] > 0, x]` o WolframAlpha `sin(x)>0`.
#
# ---
#
# # 6. Actividades de aprendizaje (sesión propuesta: 90 min en clase presencial + trabajo previo en aula invertida)
#
# **Antes de clase (Aula invertida)**
#
# * Video (10-12 min): introducción a inecuaciones lineales y cuadráticas con solución manuscrita y LaTeX (subir a GitHub/YouTube).
# * Notebook Jupyter (30–40 min): ejercicios guiados con SymPy y widgets interactivos (ver más abajo código de `ipywidgets`).
# * Lectura corta: apartes del programa y capítulo de Swokowski (capítulo sobre inecuaciones). ([Archivo de Internet][3])
#
# **En clase (sesión de 90 min)**
#
# * 0–10 min: entrada / preguntas rápidas (quiz de 3 ítems diagnóstico).
# * 10–30 min: micro-lección de conversión de registro (Duval) con mini-demostración gráfica ↔ algebraica. ([pat-thompson.net][2])
# * 30–60 min: trabajo por equipos ABPP (2 grupos resuelven inecuaciones propuestas y generan tabla tabular + gráfica).
# * 60–80 min: presentación de resultados (peer teaching).
# * 80–90 min: cierre con evidencia: capturas de notebooks y una autoevaluación (rubrica).
#
# ---
#
# # 7. Canción/poema para fijar conceptos
#
# (Un **rap académico** corto para recordar pasos de resolución)
#
# > “Primero factoriza si puedes controlar,
# > signos y ceros hay que relacionar.
# > tabla y gráfica, no puedes fallar,
# > convierte al registro para comprobar.
# > SymPy te ayuda a comprobar,
# > Matplotlib dibuja lo que vas a afirmar.”
#
# Puedes pedir a los estudiantes que lo conviertan en un breve jingle con ritmo de 8 compases y lo suban como actividad creativa (STEAMS).
#
# ---
#
# # 8. Tarea / ejercicios (20 ejercicios) + función Python para asignar tareas
#
# Diseño de **cada ejercicio**: (1) descripción geométrica del algoritmo, (2) descripción verbal y secuencial del algoritmo, (3) implementación en Python (desde PowerShell editando `.py` o `.ipynb`), (4) cálculo a mano en cuaderno.
#
# **Lista de 20 ejercicios (resumida; cada uno tiene esas 4 partes en la tarea entregada a estudiantes):**
#
# 1. Resolver \$2x-5>1\$ (lineal).
# 2. \$3-4x\le 7\$ (lineal).
# 3. \$x^2-5x+6\le 0\$ (cuadrática).
# 4. \$x^2+2x+1>0\$ (cuadrática).
# 5. \$\frac{x-1}{x+2} > 0\$ (racional).
# 6. \$\frac{x^2-1}{x-3} \le 0\$ (racional).
# 7. \$\sin x > 0\$ en $\[-\pi,\pi]\$ (trig).
# 8. \$\cos x \le 1/2\$ en $\[0,2\pi]\$ (trig).
# 9. \$e^x - 3 > 0\$ (transcendente).
# 10. \$\ln(x-1) \le 2\$ (dominio + inecuación).
# 11. Sistema: \$x-2y>0\$ y \$2x+y<5\$ (sistema lineal desigualdades).
# 12. Inecuación con valor absoluto: \$|2x-3|\le 5\$.
# 13. Problema aplicado: altura de proyectil \$h(t)\le 0\$ (root/tiempo de caída).
# 14. Buscar \$x\$ tal que \$(x-4)(x^2-1)\ge 0\$.
# 15. Resolver \$1/(x^2-4) < 0\$.
# 16. \$x^3-3x^2+2x \le 0\$ (polinomial cúbico).
# 17. Construcción de conjunto solución y comprobación con SymPy (problema combinado).
# 18. Interpretación geométrica: región del plano donde \$x^2+y^2\le 4\$ y \$y>x\$ (intersecciones).
# 19. Aproximación numérica: encontrar \$x\$ que satisface \$\tan x > 1\$ en \$(0,\pi/2)\$.
# 20. Proyecto mini: modela y resuelve una inecuación que represente un límite físico (ej. velocidad < 10m/s dada resistencia).
#
# **Función Python (asignación de tareas)**
# Este código lee la lista de estudiantes desde el archivo `.xlsx` en tu repo y asigna ejercicios en round-robin; guarda las asignaciones en `asignaciones.csv` en tu carpeta local.
#
# ```python
# import pandas as pd
# from urllib.parse import urljoin
#
# # Raw URL de GitHub (ajusta según tu repo)
# excel_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/vector_geometry_and_linear_algebra.xlsx"
#
# # Leer archivo (necesita acceso a internet desde tu Jupyter)
# df_students = pd.read_excel(excel_url)
#
# # Asegúrate que df_students tenga una columna "nombre" o "email"
# if 'nombre' not in df_students.columns:
#     # intenta columnas comunes
#     possible = [c for c in df_students.columns if 'name' in c.lower() or 'nombre' in c.lower()]
#     if possible:
#         df_students.rename(columns={possible[0]:'nombre'}, inplace=True)
#     else:
#         raise ValueError("No se encontró columna 'nombre' en el archivo de estudiantes. Revisa el xlsx.")
#
# exercises = list(range(1,21))  # 20 ejercicios
# assignments = []
# for i, row in df_students.iterrows():
#     student = row['nombre']
#     ex = exercises[i % len(exercises)]
#     assignments.append({'nombre': student, 'ejercicio_asignado': ex})
#
# df_assign = pd.DataFrame(assignments)
# df_assign.to_csv("asignaciones_inecuaciones.csv", index=False)
# print("Guardado: asignaciones_inecuaciones.csv")
# ```
#
# > Nota: el `excel_url` debe apuntar al **raw** de GitHub; si tu archivo está privado o la URL difiere, ajusta. La lectura desde GitHub requiere conexión en el entorno del estudiante.
#
# ---
#
# # 9. Evaluación
#
# ## 9.1 20 proyectos (breve lista de temas)
#
# 1. Visualizar solución de inecuaciones racionales y crear una animación que muestre desplazamiento de una raíz.
# 2. Comparar métodos simbólicos y numéricos para soluciones de inecuaciones.
# 3. Interfaz interactiva (ipywidgets) que permita cambiar coeficientes y observar la solución.
# 4. Mapear estrategias de resolución (Duval): tabla que muestre conversiones.
# 5. Proyecto aplicado: modelar límites de seguridad en un sistema físico.
#    6–20. (continuar con variaciones: inecuaciones multivariables, optimización con restricciones, proyecto STEAMS integrando arte y música para la memorización de procedimientos, etc.)
#
# (Cada proyecto debe entregar: notebook Jupyter, informe en PDF, video de demostración de 3 min).
#
# ## 9.2 Ejemplo de quiz (30 min, 3 ítems) — formato rápido
#
# 1. Resolver \$3x-7\le 2\$ y escribir la solución como intervalo. (2 pts)
# 2. Sea \$f(x)=x^2-4\$. Indica los intervalos donde \$f(x)<0\$ y justifica con tabla de signos. (3 pts)
# 3. (Interprete) Dado el gráfico de \$g(x)=(x-1)/(x+1)\$ señala las regiones donde \$g(x)>0\$ y explica por qué. (3 pts)
#
# ## 9.3 Ejemplo de parcial (90 min, 5 ítems)
#
# 1. (Teoría) Explica (breve) la diferencia entre tratamiento y conversión de representaciones según Duval. (10 pts). ([pat-thompson.net][2])
# 2. Resolver algebraica y gráficamente: \$x^2-6x+8<0\$ (20 pts).
# 3. Utilizando SymPy, determina la solución de \$\frac{x^2-1}{x-2} \ge 0\$ y exporta una tabla de evaluación en CSV (20 pts).
# 4. (Aplicado) Plantea y resuelve una inecuación que represente una restricción de un problema económico simple (ej. beneficio ≥ 0) (20 pts).
# 5. (Programación) Crea un widget que permita al usuario seleccionar la inecuación y muestre la solución simbólica y la gráfica (30 pts).
#
# ---
#
# # 10. Diseño de actividad de retroalimentación
#
# * **Formato:** rúbrica + entrega de notebook corregido con comentarios `# REVIEW` en celdas específicas.
# * **Proceso:** el estudiante sube notebook → profe marca bloques donde hubo error en conversión de registros → estudiante corrige en 48 h → peer-review de otro estudiante.
# * **Objetivo:** asegurar que la conversión entre registros (gráfico ↔ algebraic ↔ simbólico) sea correcta.
#
# ---
#
# # 11. Vocabulario y frases en inglés asociados a la clase
#
# * Inequality — desigualdad
# * Strict inequality — desigualdad estricta (>, <)
# * Non-strict inequality — desigualdad no estricta (≥, ≤)
# * Interval notation — notación de intervalo
# * Solution set — conjunto solución
# * Sign chart / sign table — tabla de signos
# * Rational inequality — inecuación racional
# * Quadratic inequality — inecuación cuadrática
# * Symbolic computation — cálculo simbólico
# * Numerical approximation — aproximación numérica
#
# Frases útiles:
#
# * "Solve the inequality \$2x-5>1\$ and express your answer in interval notation."
# * "Create a sign chart for the rational function and determine where it is positive."
# * "Use SymPy to verify your algebraic solution."
#
# ---
#
# # 12. Apéndice: habilidades socioemocionales y trabajo en equipo
#
# **Competencias a desarrollar**
#
# * Comunicación asertiva: usar lenguaje técnico preciso y feedback constructivo.
# * Empatía: valorar respuestas parciales y guiar al compañero con preguntas (¿por qué hiciste ese paso?).
# * Manejo de la ansiedad ante pruebas: técnicas de respiración, planificación del tiempo y resolución por partes.
# * Ética académica: normas sobre colaboración y citación; sanciones por fraude.
#
# **Actividad práctica de equipo (15 min)**
#
# * Ronda 1 (5 min): cada estudiante comparte un error común que le da miedo confesar.
# * Ronda 2 (5 min): compañero propone preguntas para guiar corrección.
# * Ronda 3 (5 min): breve acuerdo de normas de equipo y firma digital (Google Form).
#
# ---
#
# # 13. Referentes en didáctica de la matemática (10 + Duval + Wing) — ordenados en APA
#
# Abajo te doy 12 referencias (incluyendo Duval y Wing). Las referencias siguientes se presentan en formato APA; al integrarlas en tu documento, verifica la edición/fechas de impresión:
#
# 1. Duval, R. (2017). *Understanding the mathematical way of thinking: The registers of semiotic representations* (T. M. M. Campos, Ed.; Trans.). Springer. (Original work on registers and semiosis). ([SpringerLink][4])
# 2. Wing, J. M. (2006). *Computational thinking*. Communications of the ACM, 49(3), 33–35. (Desarrollo del pensamiento computacional). ([Wikipedia][5])
# 3. Freudenthal, H. (1991). *Mathematics as an educational task*. Kluwer.
# 4. Tall, D. (1991). *Advanced Mathematical Thinking*. Kluwer Academic Publishers.
# 5. Skemp, R. R. (1976). *Relational understanding and instrumental understanding*. Mathematics Teaching.
# 6. Polya, G. (1945). *How to Solve It*. Princeton University Press.
# 7. Dienes, Z. P. (1960). *Building up mathematics*. Hutchinson.
# 8. Vygotsky, L. S. (1978). *Mind in Society: The Development of Higher Psychological Processes*. Harvard University Press.
# 9. Presmeg, N. (2014). *Research on visualization in learning and teaching mathematics*. In *Handbook of Research on the Psychology of Mathematics Education*.
# 10. Niss, M. (1999). *Competencies and mathematical learning*. In *Educational Studies in Mathematics*.
# 11. Balacheff, N. (1988). *Aspects of proof in mathematics education*. In *Proceedings of PME XII*.
# 12. Reys, R., Lindquist, M. M., Lambdin, D. V., & Smith, N. L. (2012). *Helping Children Learn Mathematics*.
#
# > Observación: para Duval y la aplicación de registros semióticos a la enseñanza de la geometría y la resolución de problemas, ver Duval (1995, 2006, 2017). ([pat-thompson.net][2])
#
# ---
#
# ## Notas técnicas y ejemplos de código (Jupyter / VS Code)
#
# ### Importaciones recomendadas (al inicio del notebook, para garantizar visualización interactiva en VS Code)
#
# ```python
# import numpy as np
# import pandas as pd
# import sympy as sp
# import matplotlib.pyplot as plt
# import seaborn as sns
# import plotly.express as px
# import ipywidgets as widgets
# from IPython.display import display, HTML, clear_output
# from matplotlib import animation
# ```

# %% [markdown]
# ### Visualizaciones animadas (ejemplo breve)
#
# ```python
# # ejemplo: animar la raíz moviéndose para una cuadrática con parámetro a
# fig, ax = plt.subplots()
# xs = np.linspace(-5, 5, 400)
# line, = ax.plot(xs, xs**2, lw=2)
#
# def animate(i):
#     a = 1 + 0.01*i
#     ys = a*xs**2 - 4
#     line.set_ydata(ys)
#     ax.set_title(f"a={a:.3f}")
#     return (line,)
#
# ani = animation.FuncAnimation(fig, animate, frames=100, interval=50)
# # para render en Jupyter:
# HTML(ani.to_jshtml())
# ```
#
# > Recuerda: en VS Code debes poder usar `HTML(ani.to_jshtml())` y la celda mostrará la animación.

# %% [markdown]
# ### Widget interactivo simple para inecuaciones lineales
#
# a_widget = widgets.FloatSlider(value=2, min=-5, max=5, step=0.1, description='a')
# b_widget = widgets.FloatSlider(value=-5, min=-10, max=10, step=0.1, description='b')
#
# def update(a,b):
#     xs = np.linspace(-10,10,400)
#     ys = a*xs + b
#     plt.figure(figsize=(6,3))
#     plt.plot(xs, ys)
#     plt.axhline(0, color='k')
#     plt.fill_between(xs, ys, 0, where=(ys>0), alpha=0.2)
#     plt.ylim(-10,10)
#     plt.show()
#
# widgets.interact(update, a=a_widget, b=b_widget)

# %% [markdown]
# # Bibliografía / fuentes consultadas (selección de las más relevantes usadas aquí)
#
# * Repositorio de diseño IAE (tu diseño de investigación IAE). ([GitHub][1])
# * Lista de estudiantes (groups\_list). ([GitHub][6])
# * Swokowski, E. W. *Álgebra y Trigonometría con Geometría Analítica* (13ª ed.). (texto guía). ([Archivo de Internet][3])
# * Jeannette Wing — artículo y biografía (pensamiento computacional). ([Wikipedia][5])
# * Duval, R. — trabajos sobre registros semióticos y representaciones en matemáticas. ([pat-thompson.net][2])
#
# ---

# %% [markdown]
# # Cierro con 3 recomendaciones prácticas para implementación inmediata
#
# 1. **Prepara el notebook “Aula invertida”** con: video 10 min + Notebook `intro_inecuaciones.ipynb` con celdas para SymPy y widgets.
# 2. **Instala Graphviz localmente** para poder renderizar el mapa conceptual en `C:\Users\marco\Downloads` (asegúrate que `dot` esté en PATH).
# 3. **Revisa licencias de imágenes** si las vas a publicar y, si es posible, reemplázalas por tus propios bocetos o ilustraciones generadas por tu equipo.
#
# ---

# %% [markdown]
# Si quieres, preparo ahora (sin más preguntas) cualquiera de los siguientes entregables **en un solo archivo** que puedas ejecutar en Jupyter/VS Code:
#
# * El **notebook completo** `inecuaciones_notebook.ipynb` con ejemplos (SymPy, Matplotlib, widgets, animaciones) listo para subir a GitHub.
# * El **quiz 1** en .docx (con símbolos unicode) que pediste antes.
# * El **mapa conceptual** ya renderizado y exportado como PDF en tu ruta `C:\Users\marco\Downloads` (si confirmas que Graphviz está instalado en tu máquina, te doy el comando listo para ejecutar).
#
# Dime cuál de estos prefieres que genere ahora (te entregaré el archivo / notebook listo para descargar) y lo hago de inmediato.
#
# [1]: https://github.com/marco-canas/algebra_y_trigonometria/blob/main/1_plan_curso/0_dise%C3%B1o_invts_IAE.md "algebra_y_trigonometria/1_plan_curso/0_diseño_invts_IAE.md at main · marco-canas/algebra_y_trigonometria · GitHub"
# [2]: https://pat-thompson.net/PDFversions/1999Duval.pdf?utm_source=chatgpt.com "representation, vision and visualization: cognitive functions"
# [3]: https://archive.org/details/algebra-y-trigonometria-con-geometria-analitica-13va-edicion-earl-w.-swokowski/page/n3/mode/2up "Álgebra Y Trigonometría Con Geometría Analítica, 13va Edición Earl W. Swokowski : Free Download, Borrow, and Streaming : Internet Archive"
# [4]: https://link.springer.com/book/10.1007/978-3-319-56910-9?utm_source=chatgpt.com "Understanding the Mathematical Way of Thinking"
# [5]: https://es.wikipedia.org/wiki/Jeannette_Wing "Jeannette Wing - Wikipedia, la enciclopedia libre"
# [6]: https://github.com/marco-canas/groups_list/blob/main/vector_geometry_and_linear_algebra.xlsx "groups_list/vector_geometry_and_linear_algebra.xlsx at main · marco-canas/groups_list · GitHub"

# %% [markdown]
# # [Programación de programa Regiones](https://lookerstudio.google.com/reporting/44e71da0-d16f-4a51-a51e-d5ae6c19b3f1/page/p_gy4nwf37hd?pli=1)

# %% [markdown]
# # Cursos que orienta el profesor Marco Julio Cañas Campillo en 2025
#
# 1. Lunes 8 a 12: Fundamentos de Lógica: Licenciatura en Matemáticas .
# 2. Martes de 9 a 11: Álgebra y Trigonometría.
# 3. Martes de 2 a 6 PM: Vector Geometry and Linear Algebra.
# 4. Miércoles: 10 a 11: Reunión equipo investigador SAT Dengue.
# 5. Miércoles 2 a 3 PM: Asesoría Trabajo de Grado Janis (Estudiante de Biología).
# 6. Viernes 8 a 12 PM: Análisis Numérico: Programa de Licenciatura en Matemáticas.
# 7. Sábajo:

# %% [markdown]
# # Horario de clases del profesor Marco
#
# * Lunes 8-12: Fundamento de Lógica.
# * Martes 8-12 M: .
# * Miércoles 8 a 12 M:
# * Miércoles de 2 a 6 PM:
# * Jueves 2 a 6 PM:
# * Viernes 2 - 4 PM: Análisis Numérico.
# * Sábados 8-12 Asesorías y espacio para retroalimentación y apoyo al trabajo independiente.

# %% [markdown]
# # Horarios de monitoría y asesoría
#
# * Monitor José Luis Guerrero Guerra: Contactar escribiendo al correo:

# %% [markdown]
# Coordinador de los cursos de la Facultad de Educación para regiones:
#
# Andrés Vélez: regioneducacion.fedu@udea.edu.co
# Coordinador Regiones
# Facultad de Educación
# Universidad de Antioquia

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [CALCULO I DE UNA VARIABLE Ron Larson-Bruce Edwards. Mc Graw Hill. 9º Edición](https://www.academia.edu/42139251/CALCULO_I_DE_UNA_VARIABLE_Ron_Larson_Bruce_Edwards_Mc_Graw_Hill_9o_Edici%C3%B3n)
#
#
# * [Grajales Vanegas, L. M., Restrepo Estrada, C. E., Restrepo Ochoa, S. I., & Ruíz De Villalba, F. (2015). Matemáticas I para las ciencias económicas.](https://bibliotecadigital.udea.edu.co/handle/10495/3010)
#
# * R. Duval y Semiosis y pensamiento humano, 2.ª ed. Cali, Colombia: Programa Editorial Universidad del Valle, 2017. [En línea]. Disponible en: https://programaeditorial.univalle.edu.co/gpd-semiosis-y-pensamiento-humano-9789587655278-63324cdb0f6b3.html
#
# * [Aylwin, C. U. (2011). Lógica, conjuntos y números. Universidad de los Andes, Consejo de Publicaciones, Colección: Ciencias Básicas, Serie: Matemáticas.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.u-cursos.cl/ciencias/2011/1/MC110/1/material_docente/bajar?id_material=574722)
#
# * [Chollet, F. (2021). Deep learning with Python. Simon and Schuster.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://tanthiamhuat.wordpress.com/wp-content/uploads/2018/03/deeplearningwithpython.pdf)
#
# * [Watson, S., Stewart, J., & Redlin, L. (2009). Precálculo. Matemáticas para el cálculo.](https://github.com/marco-canas/calculo/blob/main/referents/1_precalculo_stewart/stewart_precalculo.pdf)
#
# * [Purcell, E. J., Varberg, D., & Rigdon, S. E. (2007). Cálculo diferencial e integral. Pearson Educación.](https://github.com/marco-canas/calculo/blob/main/referents/purcell/purcell_calculo.pdf)
#
#
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
#
#
#
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
#
# * [Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/http://14.139.161.31/OddSem-0822-1122/Hands-On_Machine_Learning_with_Scikit-Learn-Keras-and-TensorFlow-2nd-Edition-Aurelien-Geron.pdf)

# %% [markdown]
# * [McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".](https://wesmckinney.com/book/)

# %% [markdown]
# # Como estudiante, encuentro que...
#
# F: Mis Fortalezas son:
# O: Mis Oportunidades son:
# D: Mis Debilidades son:
# A: Lo que Amenazas mi aprendizaje es:

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado. Este hijo me enorgullece y me hace falta abrazarlo cada día.
#
# Y a mi esposa Yasmira Emperatriz Barboza Mogollón por su apoyo, orientación y acompañamiento.

# %% [markdown]
# # Apéndice sobre calendarios y coordinaciones

# %% [markdown]
# ## Calendario del semestre académico 2025-2
#
# * Límite evaluación del 40%: 27 de septiembre de 2025
#
# * Terminación de clases: 22 de noviembre de 2025
#
# * Exámenes finales: 24 al 29 de noviembre de 2025
#
# * Habilitación y validación: 01 al 06 de diciembre 2025
#
# * Terminación oficial del semestre: 09 de diciembre de 2025
