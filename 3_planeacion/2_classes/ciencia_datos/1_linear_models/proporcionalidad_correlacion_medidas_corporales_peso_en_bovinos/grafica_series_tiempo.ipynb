# %% [markdown]
# # Grafica de peso Vs tiempo

# %% [markdown]
# # Obtener los datos

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

edad = np.array(["hembras < 1 año", "hembras 1 a 2 años", "hembras 2 a 3 años",\
                 "hembras 3 a 4 años", "hembras 4 a 5 años", "hembras 5 a 6 años", \
                 "hembras 6 a 7 años", "hembras 7 a 8 años" ])

peso = np.array([96.8, 217.8, 375, 413.7, 435.6, 462, 469, 464.3])
plt.figure(figsize = (14,8)) 
plt.scatter(edad, peso)
plt.grid()
