# %% [markdown]
# # Prompt para el diseño del quiz 3 de la unidad 2 del texto de Álgebra y Trigonometría de Swokowski
#
# Dame por favor, un diseño de un quiz de 8 preguntas para evaluar los temas vistos en la unidad 2 del texto de Álgebra y Trigonometría de Swokowski. Cada pregunta debe ser clara y concisa, y debe cubrir uno de los temas listados a continuación. Asegúrate de que las preguntas sean variadas y aborden diferentes aspectos de cada tema.
#
# Temas a evaluar:
#
# 1. Ecuaciones lineales $ax + b = 0$.
# 2.  La altura sobre el suelo h (en pies) de un cohete de juguete, t segundos después que es lanzado, está dada por $h = -16t^{2} + 120t$ . ¿Cuándo estará el cohete a 100 pies sobre el suelo?
#
# 3. Ecuaciones cuadráticas $ax^2 + bx + c = 0$.
# 4. Deduzca, utilizando el método de completación del trinomio cuadrado perfecto, la solución general de la ecuaciónb cuadrática $x^2 + bx + c = 0$. Ojo, el coeficiente líder es 1.
# 5. Ecuaciones racionales $\frac{P(x)}{Q(x)} = 0$.
# 6. Una caja con base cuadrada y sin tapa ha de construirse de una pieza cuadrada de hojalata al cortar un cuadrado de 3 pulgadas de cada esquina y doblar los lados. Si la caja debe contener 48 pulg3, ¿de qué tamaño debe ser la pieza de hojalata que debe usarse?
# 7. Inecuaciones lineales $ax + b < 0$.
# 8. Inceuaciones racionales $\frac{P(x)}{Q(x)} < 0$.

# %% [markdown]
# Perfecto ✨ Aquí tienes un **quiz de 8 preguntas**, diseñado a partir de los temas de la Unidad 2 del texto *Álgebra y Trigonometría* de Swokowski. Las preguntas son claras, concisas y variadas, incluyendo problemas conceptuales y aplicados:
#
# ---
#
# # **Quiz Unidad 2 – Álgebra y Trigonometría (Swokowski)**
#
# **Tiempo sugerido:** 50 minutos
# **Número de preguntas:** 8
#
# ---
#
# ### **1. Ecuaciones lineales**
#
# Resuelva la ecuación lineal:
#
# $$
# 7x - 14 = 0
# $$
#
# ---
#
# ### **2. Aplicación con función cuadrática (cohete de juguete)**
#
# La altura sobre el suelo $h$ (en pies) de un cohete de juguete, $t$ segundos después de lanzado, está dada por:
#
# $$
# h = -16t^{2} + 120t
# $$
#
# ¿Cuándo estará el cohete a 100 pies sobre el suelo?
#
# ---
#
# ### **3. Ecuaciones cuadráticas**
#
# Resuelva la ecuación cuadrática:
#
# $$
# 2x^2 - 3x - 5 = 0
# $$
#
# ---
#
# ### **4. Método de completación de trinomio cuadrado perfecto**
#
# Deduzca, utilizando el método de completación del trinomio cuadrado perfecto, la solución general de la ecuación:
#
# $$
# x^2 + bx + c = 0
# $$
#
# (suponiendo que el coeficiente líder es 1).
#
# ---
#
# ### **5. Ecuaciones racionales**
#
# Resuelva la siguiente ecuación racional:
#
# $$
# \frac{x^2 - 9}{x + 3} = 0
# $$
#
# ---
#
# ### **6. Problema aplicado (caja sin tapa)**
#
# Una caja con base cuadrada y sin tapa se construye a partir de una lámina cuadrada de hojalata cortando cuadrados de 3 pulgadas de cada esquina y doblando los lados.
# Si la caja debe contener 48 pulgadas cúbicas, ¿de qué tamaño debe ser la lámina cuadrada original?
#
# ---
#
# ### **7. Inecuaciones lineales**
#
# Resuelva la inecuación:
#
# $$
# 5x + 7 < 2
# $$
#
# ---
#
# ### **8. Inecuaciones racionales**
#
# Resuelva la inecuación racional:
#
# $$
# \frac{x - 4}{x + 1} < 0
# $$
#
# ---
#
# ¿Quieres que ahora te prepare también el **script en Python para convertir este quiz a `.docx` con notación Unicode** (como hicimos antes), o prefieres que primero dejemos este diseño listo para impresión en PDF/Word sin código?

# %% [markdown]
# # Prompt para convertir a formato .docx
#
# Dame el script de Python para convertir en archivo .docx a este quiz, sin utilizar latex, y utilizando símbolos unicode para hacer legible mas expresiones matemáticas, por favor, presenta las expresiones fraccionarias con notación a dos líneas para facilitar su legibilidad.

# %%
from docx import Document
from docx.shared import Pt

# Crear documento
doc = Document()
doc.add_heading("Quiz Unidad 2 – Álgebra y Trigonometría (Swokowski)", level=1)

# Datos generales
doc.add_paragraph("⏱️ Tiempo sugerido: 50 minutos")
doc.add_paragraph("📘 Número de preguntas: 8")
doc.add_paragraph(" ")

# =========================
# PREGUNTA 1
# =========================
doc.add_paragraph("1. Resuelva la ecuación lineal:")
doc.add_paragraph("   7x − 14 = 0")

# =========================
# PREGUNTA 2
# =========================
doc.add_paragraph("2. Aplicación con función cuadrática (cohete de juguete):")
doc.add_paragraph("   La altura sobre el suelo h (en pies) de un cohete de juguete, t segundos después de lanzado, está dada por:")
doc.add_paragraph("   h = −16t² + 120t")
doc.add_paragraph("   ¿Cuándo estará el cohete a 100 pies sobre el suelo?")

# =========================
# PREGUNTA 3
# =========================
doc.add_paragraph("3. Resuelva la ecuación cuadrática:")
doc.add_paragraph("   2x² − 3x − 5 = 0")

# =========================
# PREGUNTA 4
# =========================
doc.add_paragraph("4. Método de completación del trinomio cuadrado perfecto:")
doc.add_paragraph("   Deduzca, utilizando el método de completación del trinomio cuadrado perfecto, la solución general de:")
doc.add_paragraph("   x² + bx + c = 0")
doc.add_paragraph("   (Suponga que el coeficiente líder es 1).")

# =========================
# PREGUNTA 5
# =========================
doc.add_paragraph("5. Resuelva la siguiente ecuación racional:")
doc.add_paragraph("       x² − 9")
doc.add_paragraph("   ――――――――――――  = 0")
doc.add_paragraph("       x + 3")

# =========================
# PREGUNTA 6
# =========================
doc.add_paragraph("6. Problema aplicado (caja sin tapa):")
doc.add_paragraph("   Una caja con base cuadrada y sin tapa se construye a partir de una lámina cuadrada de hojalata cortando cuadrados de 3 pulgadas")
doc.add_paragraph("   en cada esquina y doblando los lados. Si la caja debe contener 48 pulgadas³, ¿de qué tamaño debe ser la lámina original?")

# =========================
# PREGUNTA 7
# =========================
doc.add_paragraph("7. Resuelva la siguiente inecuación lineal:")
doc.add_paragraph("   5x + 7 < 2")

# =========================
# PREGUNTA 8
# =========================
doc.add_paragraph("8. Resuelva la siguiente inecuación racional:")
doc.add_paragraph("       x − 4")
doc.add_paragraph("   ――――――――――――  < 0")
doc.add_paragraph("       x + 1")

# Ajustes finales de estilo
for p in doc.paragraphs:
    for run in p.runs:
        run.font.size = Pt(12)

# Guardar el documento
doc.save("Quiz_Unidad2.docx")
print("✅ Archivo 'Quiz_Unidad2.docx' generado correctamente.")
# Out:
# ✅ Archivo 'Quiz_Unidad2.docx' generado correctamente.
