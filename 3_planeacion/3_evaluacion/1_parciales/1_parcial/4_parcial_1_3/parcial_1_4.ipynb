# %% [markdown]
# Perfecto, Marco. Te propongo un **diseño de parcial** ajustado al estilo IMUA y a los temas **1.1–1.4** del Swokowski (Números reales, exponentes y radicales, expresiones algebraicas y fraccionarias).
#
# ---
#
# # **Instituto de Matemáticas - Universidad de Antioquia (IMUA)**
#
# ### **Parcial 1 – Álgebra y Trigonometría**
#
# **Duración:** 2 horas
# **Puntaje total:** 100 (20 puntos por ítem)
#
# ---
#
# ## **1. Teoría y Definiciones (20 puntos)**
#
# Responda de manera breve y clara:
#
# a) (5 pts) Explique por qué el conjunto de los números reales es **cerrado** bajo la suma y la multiplicación, pero no bajo la radicación par.
#
# b) (5 pts) Defina con sus palabras qué significa **simplificar una expresión algebraica**.
#
# c) (5 pts) ¿Qué es la **racionalización** de un denominador? Dé un ejemplo sencillo.
#
# d) (5 pts) Explique la diferencia entre un **polinomio** y una **expresión fraccionaria**.
#
# ---
#
# ## **2. Operaciones con Radicales y Exponentes (20 puntos)**
#
# Resuelva mostrando todos los pasos:
#
# a) (10 pts) Simplifique la expresión:
#
# $$
# \frac{ \sqrt[3]{54x^4 y^5} }{ \sqrt[3]{2x y} }
# $$
#
# b) (10 pts) Racionalice y simplifique:
#
# $$
# \frac{5}{2 + \sqrt{3}}
# $$
#
# ---
#
# ## **3. Productos Notables y Factorización (20 puntos)**
#
# a) (10 pts) Desarrolle completamente el producto notable:
#
# $$
# (x + 2y)^3
# $$
#
# b) (10 pts) Factorice la expresión:
#
# $$
# 6x^2 - 15x - 21
# $$
#
# ---
#
# ## **4. Expresiones Fraccionarias (20 puntos)**
#
# Simplifique lo siguiente paso a paso:
#
# a) (10 pts)
#
# $$
# \frac{x^2 - 4}{x^2 - 2x} \cdot \frac{x - 2}{x + 2}
# $$
#
# b) (10 pts)
#
# $$
# \frac{3}{x} - \frac{2}{x^2}
# $$
#
# ---
#
# ## **5. Problema Integrador (20 puntos)**
#
# Un agricultor necesita **cercar un terreno rectangular** con dimensiones expresadas en función de una variable $x$:
#
# * Largo: $2x + 4$ metros
# * Ancho: $x + 3$ metros
#
# a) (10 pts) Exprese el **perímetro** y el **área** en función de $x$. Simplifique cada expresión.
#
# b) (10 pts) Si $x = \sqrt{9}$, calcule el perímetro y el área. Justifique cada paso usando las propiedades de los números reales, radicales y productos notables.
#
# ---
#
# ### **Notas de estilo IMUA**
#
# * **Claridad y justificación:** Cada resultado debe ir acompañado de pasos intermedios.
# * **Notación rigurosa:** No se aceptan resultados escritos sin indicar operaciones.
# * **Dificultad progresiva:** Los problemas avanzan de lo mecánico a lo integrador.
#
# ---
#
# ¿Quieres que también te arme la **rúbrica de calificación** (con criterios: exactitud, orden, justificación, uso de notación) para este parcial?
