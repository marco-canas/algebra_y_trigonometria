# %% [markdown]
# # Prompt  para el diseño del parcial 1
#
# Dame el diseño de parcial para evaluar las siguientes secciones del texto: https://archive.org/details/algebra-y-trigonometria-con-geometria-analitica-13va-edicion-earl-w.-swokowski:
#
# 1.1 Números reales
# 1.2 Exponentes y radicales: Racionalización y simplificación.
# 1.3 Expresiones algebraicas: productos notables, factorización.
# 1.4 Expresiones fraccionarias; multiplicación, división, suma y resta de fracciones. Simplificación de fracciones algebraicas.
#
# Pero que este diseño de parcial sea siguiendo la estructura:
#
#
# ### **Parcial de Álgebra y Trigonometría**
# **Duración**: 2 horas
# **Puntos totales**: 100 (20 puntos por ítem).
#
# #### **1. Teoría y Definiciones (20 puntos)**
# - Preguntas conceptuales cortas sobre:
#   - Definiciones básicas (e.g., *¿Qué es un número complejo en forma polar?*).
#   - Propiedades de funciones algebraicas o trigonométricas (e.g., *Enuncie la identidad pitagórica fundamental*).
#   - Justificaciones breves (e.g., *¿Por qué la función \( f(x) = \sqrt{x} \) no está definida para \( x < 0 \) en los reales?*).
#
# #### **2. Resolución de Ecuaciones y Sistemas (20 puntos)**
# - Problemas que requieran resolver:
#   - Ecuaciones algebraicas (lineales, cuadráticas o con valor absoluto).
#   - Sistemas de ecuaciones lineales (2x2 o 3x3).
#   - Ecuaciones trigonométricas básicas (e.g., \( \sin(x) = \frac{1}{2} \)).
#
# #### **3. Aplicación de Identidades Trigonométricas (20 puntos)**
# - Demostrar identidades trigonométricas usando fórmulas fundamentales.
# - Simplificar expresiones trigonométricas complejas.
# - Ejemplo: *Demuestre que \( \sec^2(x) - \tan^2(x) = 1 \)*.
#
# #### **4. Problemas de Aplicación (20 puntos)**
# - Contextualización en problemas reales o geométricos, como:
#   - Ley de senos/cosenos en triángulos.
#   - Modelación con funciones (e.g., altura máxima de un proyectil).
#   - Aplicaciones de números complejos (e.g., representación gráfica).
#
# #### **5. Desarrollo y Análisis (20 puntos)**
# - Pregunta abierta que integre varios temas, por ejemplo:
#   - Analizar y graficar una función combinada (algebraica y trigonométrica).
#   - Justificar soluciones o interpretar gráficas (e.g., *Dada \( f(x) = 2\sin(x) + 1 \), determine amplitud, período y desplazamiento*).
#
# ### **Notas adicionales**:
# - **Estilo IMUA**: Las preguntas suelen ser directas pero requieren precisión. Se valora la claridad en los pasos y el uso correcto de notación matemática.
# - **Enfoque**: Combinación de habilidades básicas (cálculo) y pensamiento crítico (justificación teórica).
# - **Dificultad**: Progresiva, desde ítems mecánicos hasta problemas integradores.
#
# Esta estructura refleja el equilibrio entre teoría y práctica característico del IMUA, asegurando que los estudiantes demuestren comprensión profunda y habilidades técnicas."
#
# Incluye en el parcial un sexto punto (opcional) que consista en resolver el siguiente problema geométrico: "Encuentre los volúmenes de las cajas I, II y II de la figura para establecer la fórmula de la diferencia de dos cubos para el caso especial $x > y$."
#
# En este parcial, no incluyas puntos donde se pregunte sobre ecuaciones con radicales o sistemas de ecuaciones o fracciones parciales o racionalización de fracciones, pues estos temas no se han visto en clase.

# %% [markdown]
# Perfecto, Marco. Con la aclaración de que **no se han visto aún ecuaciones con radicales, sistemas de ecuaciones, fracciones parciales ni racionalización de fracciones**, te propongo un diseño de **Parcial 1** totalmente alineado con el contenido **1.1–1.4** de Swokowski y la estructura IMUA que mencionaste.
#
# ---
#
# # **Instituto de Matemáticas - Universidad de Antioquia (IMUA)**
#
# ### **Parcial 1 – Álgebra y Trigonometría**
#
# **Duración:** 2 horas
# **Puntaje total:** 100 (20 puntos por ítem).
# **Nota:** Se evaluará claridad, orden lógico, justificación de pasos y uso correcto de la notación matemática.
#
# ---
#
# ## **1. Teoría y Definiciones (20 puntos)**
#
# Responda de manera breve y clara:
#
# a) (5 pts) ¿Qué se entiende por **número real**? Dé un ejemplo de cada subconjunto: enteros, racionales e irracionales.
#
# b) (5 pts) Enuncie dos propiedades de los **exponentes** y dos propiedades de los **radicales**.
#
# c) (5 pts) ¿Qué son los **productos notables** y por qué facilitan los cálculos algebraicos?
#
# d) (5 pts) ¿Qué es una **expresión fraccionaria algebraica**? Dé un ejemplo.
#
# ---
#
# ## **2. Operaciones con Números Reales y Radicales (20 puntos)**
#
# Resuelva mostrando todos los pasos:
#
# a) (10 pts) Simplifique la expresión:
#
# $$
# \frac{ \sqrt[3]{16x^4 y^7} }{ \sqrt[3]{2x y} }
# $$
#
# b) (10 pts) Simplifique:
#
# $$
# \sqrt{50} - \sqrt{18} + \sqrt{8}
# $$
#
# ---
#
# ## **3. Productos Notables y Factorización (20 puntos)**
#
# a) (10 pts) Desarrolle completamente:
#
# $$
# (x + 3y)^2
# $$
#
# b) (10 pts) Factorice la expresión:
#
# $$
# x^2 - 9x + 20
# $$
#
# ---
#
# ## **4. Expresiones Fraccionarias (20 puntos)**
#
# Simplifique cada una mostrando los pasos:
#
# a) (10 pts)
#
# $$
# \frac{x^2 - 4}{x^2 - 2x} \cdot \frac{x - 2}{x + 2}
# $$
#
# b) (10 pts)
#
# $$
# \frac{3}{x} + \frac{2}{x^2}
# $$
#
# ---
#
# ## **5. Problema de Aplicación (20 puntos)**
#
# Un rectángulo tiene dimensiones expresadas en función de una variable $x$:
#
# * Largo: $2x + 4$ metros
# * Ancho: $x + 2$ metros
#
# a) (10 pts) Exprese el **perímetro** y el **área** en función de $x$.
#
# b) (10 pts) Si $x = \sqrt{9}$, calcule el perímetro y el área. Explique cómo usó propiedades de los números reales y de los radicales.
#
# ---
#
# ## **6. Problema Opcional – Geometría y Factorización (10 puntos adicionales)**
#
# Considere dos cubos de arista $x$ y $y$ con $x > y$.
#
# a) Calcule los volúmenes de los cubos I ($x^3$) y II ($y^3$).
# b) Exprese la diferencia de volúmenes $x^3 - y^3$.
# c) Muestre cómo se factoriza esta diferencia en la forma:
#
# $$
# x^3 - y^3 = (x-y)(x^2 + xy + y^2).
# $$
#
# ---

# %% [markdown]
# 📌 Con este diseño:
#
# * El **punto 1** garantiza comprensión conceptual.
# * Los **puntos 2–4** cubren operaciones con números reales, radicales, productos notables, factorización y fracciones algebraicas (sin ir más allá de lo visto).
# * El **punto 5** integra en un contexto aplicado.
# * El **punto 6 opcional** conecta geometría y factorización de polinomios (diferencia de cubos).
#
# ---
#
# ¿Quieres que ahora te prepare la **rúbrica de calificación detallada por ítems (criterios y niveles de desempeño)** para este parcial?

# %% [markdown]
# ¡De una, Marco! Aquí tienes **(1) la rúbrica de evaluación detallada** y **(2) un script de Python** para generar el parcial en **.docx** (todo en una línea, sin LaTeX).
#
# ---
#
# # Rúbrica de evaluación (100 pts + 10 opcionales)
#
# ## Ítem 1. Teoría y Definiciones (20 pts)
#
# * **Exactitud conceptual (8 pts):** definiciones correctas, sin confusiones entre reales/racionales/irracionales.
# * **Propiedades bien enunciadas (6 pts):** exponentes y radicales formuladas con condiciones (índice, base).
# * **Ejemplos pertinentes (4 pts):** ejemplos que realmente ilustran el concepto.
# * **Claridad y notación (2 pts):** frases completas y símbolos apropiados.
#
# ## Ítem 2. Operaciones con números reales y radicales (20 pts)
#
# * **Aplicación de propiedades (8 pts):** leyes de índices, extracción de factores, simplificación correcta.
# * **Procedimiento y orden (6 pts):** pasos lógicos, sin “saltos”.
# * **Resultado final simplificado (4 pts):** radicales sin potencias innecesarias, sin raíces en denominador si procede.
# * **Presentación (2 pts):** organización, legibilidad.
#
# ## Ítem 3. Productos notables y factorización (20 pts)
#
# * **Desarrollo correcto de productos notables (8 pts):** combinaciones y coeficientes exactos.
# * **Factorización adecuada (8 pts):** elección del método (trinomio, diferencia de cuadrados, agrupación).
# * **Verificación o contraste (2 pts):** chequeo mental o breve justificación.
# * **Notación y orden (2 pts).**
#
# ## Ítem 4. Expresiones fraccionarias (20 pts)
#
# * **Reducción por factores (8 pts):** cancelaciones válidas indicando restricciones de dominio cuando aplique.
# * **Operaciones entre fracciones (6 pts):** productos, sumas o restas correctas.
# * **Resultado final simplificado (4 pts).**
# * **Claridad (2 pts).**
#
# ## Ítem 5. Problema de aplicación (20 pts)
#
# * **Modelado correcto (8 pts):** traducción a expresiones de perímetro y área sin errores.
# * **Cálculo numérico (6 pts):** sustitución y cuentas precisas.
# * **Justificación con propiedades (4 pts):** uso explícito de propiedades de radicales y reales.
# * **Presentación y unidades (2 pts).**
#
# ## Ítem 6. Opcional – Diferencia de cubos (hasta 10 pts extra)
#
# * **Cálculo de volúmenes (4 pts):** x^3 y y^3 correctamente.
# * **Deducción de x^3 − y^3 (4 pts):** conexión geométrica y forma factorizada (x − y)(x^2 + xy + y^2).
# * **Claridad (2 pts).**
#
# > **Criterios transversales** (aplican en todos los ítems): notación rigurosa, orden lógico, y resultado final claramente identificado.
#
# ---
#
# # Script de Python para generar el parcial en .docx
#
# **Requisitos**
#
# 1. Tener Python 3.8+
# 2. Instalar: `pip install python-docx`
#
# El documento usa texto en una línea (sin LaTeX), con secciones y puntos asignados. Puedes ajustar fácilmente cualquier enunciado.

# %%
# -*- coding: utf-8 -*-
"""
Genera el 'Parcial 1 – Álgebra y Trigonometría' en formato .docx
Requiere: pip install python-docx
Las expresiones se escriben en una línea y sin LaTeX.
"""

from docx import Document
from docx.shared import Pt, Inches
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.oxml.ns import qn
from docx.enum.style import WD_STYLE_TYPE

def add_heading(doc, text, level=0):
    h = doc.add_heading(text, level=level)
    return h

def add_para(doc, text, bold=False, italic=False):
    p = doc.add_paragraph()
    run = p.add_run(text)
    run.bold = bold
    run.italic = italic
    return p

def add_spacer(doc, lines=1):
    for _ in range(lines):
        doc.add_paragraph("")

def set_base_styles(doc):
    # Fuente base
    style = doc.styles['Normal']
    style.font.name = 'Calibri'
    style._element.rPr.rFonts.set(qn('w:eastAsia'), 'Calibri')
    style.font.size = Pt(11)

    # Estilo para enunciados de ítem
    if 'Item' not in [s.name for s in doc.styles]:
        item_style = doc.styles.add_style('Item', WD_STYLE_TYPE.PARAGRAPH)
        item_style.font.name = 'Calibri'
        item_style.font.size = Pt(12)
        item_style.font.bold = True

    # Estilo para puntos y subítems
    if 'Enunciado' not in [s.name for s in doc.styles]:
        en_style = doc.styles.add_style('Enunciado', WD_STYLE_TYPE.PARAGRAPH)
        en_style.font.name = 'Calibri'
        en_style.font.size = Pt(11)

def build_parcial_doc(filename="Parcial_Algebra_Trig_Parcial1_IMUA.docx"):
    doc = Document()
    set_base_styles(doc)

    # Encabezado institucional
    title = doc.add_paragraph()
    title.alignment = WD_ALIGN_PARAGRAPH.CENTER
    r = title.add_run("Instituto de Matemáticas - Universidad de Antioquia (IMUA)")
    r.bold = True
    r.font.size = Pt(14)

    add_para(doc, "Parcial 1 – Álgebra y Trigonometría", bold=True)
    add_para(doc, "Duración: 2 horas")
    add_para(doc, "Puntaje total: 100 (20 puntos por ítem).")
    add_para(doc, "Nota: Se evaluará claridad, orden lógico, justificación de pasos y uso correcto de la notación matemática.")
    add_spacer(doc)

    # Ítem 1
    add_para(doc, "1. Teoría y Definiciones (20 pts)", bold=True)
    add_para(doc, "Responda de manera breve y clara:", italic=True)
    add_para(doc, "a) (5 pts) ¿Qué se entiende por número real? Dé un ejemplo de cada subconjunto: enteros, racionales e irracionales.")
    add_para(doc, "b) (5 pts) Enuncie dos propiedades de los exponentes y dos propiedades de los radicales (incluya condiciones).")
    add_para(doc, "c) (5 pts) ¿Qué son los productos notables y por qué facilitan los cálculos algebraicos?")
    add_para(doc, "d) (5 pts) ¿Qué es una expresión fraccionaria algebraica? Dé un ejemplo.")
    add_spacer(doc)

    # Ítem 2
    add_para(doc, "2. Operaciones con números reales y radicales (20 pts)", bold=True)
    add_para(doc, "Resuelva mostrando todos los pasos:", italic=True)
    add_para(doc, "a) (10 pts) Simplifique: (raíz cúbica de (16*x^4*y^7)) / (raíz cúbica de (2*x*y)).")
    add_para(doc, "b) (10 pts) Simplifique: sqrt(50) - sqrt(18) + sqrt(8).")
    add_spacer(doc)

    # Ítem 3
    add_para(doc, "3. Productos notables y factorización (20 pts)", bold=True)
    add_para(doc, "a) (10 pts) Desarrolle completamente: (x + 3*y)^2.")
    add_para(doc, "b) (10 pts) Factorice: x^2 - 9*x + 20.")
    add_spacer(doc)

    # Ítem 4
    add_para(doc, "4. Expresiones fraccionarias (20 pts)", bold=True)
    add_para(doc, "Simplifique mostrando los pasos:", italic=True)
    add_para(doc, "a) (10 pts) ((x^2 - 4) / (x^2 - 2*x)) * ((x - 2) / (x + 2)).")
    add_para(doc, "b) (10 pts) (3/x) + (2/x^2).")
    add_spacer(doc)

    # Ítem 5
    add_para(doc, "5. Problema de aplicación (20 pts)", bold=True)
    add_para(doc, "Un rectángulo tiene largo = 2*x + 4 y ancho = x + 2.")
    add_para(doc, "a) (10 pts) Exprese el perímetro y el área en función de x.")
    add_para(doc, "b) (10 pts) Si x = sqrt(9), calcule el perímetro y el área. Explique las propiedades usadas.")
    add_spacer(doc)

    # Ítem 6 (opcional)
    add_para(doc, "6. (Opcional) Geometría y factorización – Diferencia de cubos (hasta 10 pts)", bold=True)
    add_para(doc, "Considere dos cubos de aristas x y y con x > y.")
    add_para(doc, "a) Calcule los volúmenes: x^3 y y^3.")
    add_para(doc, "b) Exprese x^3 - y^3 y factorícelo como (x - y)(x^2 + x*y + y^2).")
    add_spacer(doc)

    # Rúbrica (resumen pegado al final para el docente)
    add_para(doc, "Rúbrica de evaluación (resumen)", bold=True)
    add_para(doc, "- Ítem 1: Exactitud conceptual (8), Propiedades (6), Ejemplos (4), Claridad (2).")
    add_para(doc, "- Ítem 2: Propiedades (8), Procedimiento (6), Resultado simplificado (4), Presentación (2).")
    add_para(doc, "- Ítem 3: Desarrollo (8), Factorización (8), Verificación (2), Notación (2).")
    add_para(doc, "- Ítem 4: Reducción por factores (8), Operaciones (6), Resultado (4), Claridad (2).")
    add_para(doc, "- Ítem 5: Modelado (8), Cálculo numérico (6), Justificación (4), Presentación (2).")
    add_para(doc, "- Ítem 6 (opcional): Volúmenes (4), Deducción y factorización (4), Claridad (2).")

    doc.save(filename)
    return filename

if __name__ == "__main__":
    fname = build_parcial_doc()
    print(f"Documento generado: {fname}")
# Out:
# Documento generado: Parcial_Algebra_Trig_Parcial1_IMUA.docx

# %% [markdown]
# ## Cómo usar
#
# 1. Guarda el script como `generar_parcial_imua.py`.
# 2. Instala dependencia: `pip install python-docx`
# 3. Ejecuta: `python generar_parcial_imua.py`
# 4. Obtendrás `Parcial_Algebra_Trig_Parcial1_IMUA.docx` en el directorio actual.
#
# ¿Quieres que también te deje un **script paralelo** para generar la **rúbrica en .docx** (en formato de tabla con criterios y puntajes) o ¿prefieres integrarla en el mismo archivo con una tabla al final?

# %% [markdown]
# Para esta situación, la representación gráfica debe mostrar un **cubo grande de lado $x$**, del cual se sustrae un cubo pequeño de lado \$y\$ para obtener la identidad:
#
# $$
# x^3 - y^3 = (x-y)(x^2 + xy + y^2)
# $$
#
# La descomposición en volúmenes (cajas I, II y III) se usa para visualizar esa factorización.
# Te propongo un **script en Python** que:
#
# 1. Usa **matplotlib** en 3D para representar los cubos.
# 2. Dibuja las **líneas de cota** (dimensiones $x$ y $y$).
# 3. Colorea las cajas para diferenciarlas.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import numpy as np
from matplotlib.patches import Patch

def draw_cuboid(ax, origin, size, color='C0', alpha=0.4, edgecolor='k', linewidth=1.2):
    """Dibuja un paralelepípedo (cuboid) en 3D dado origen (ox,oy,oz) y tamaño (dx,dy,dz)."""
    ox, oy, oz = origin
    dx, dy, dz = size
    # vértices
    v = np.array([
        [ox,     oy,     oz    ],
        [ox+dx,  oy,     oz    ],
        [ox+dx,  oy+dy,  oz    ],
        [ox,     oy+dy,  oz    ],
        [ox,     oy,     oz+dz ],
        [ox+dx,  oy,     oz+dz ],
        [ox+dx,  oy+dy,  oz+dz ],
        [ox,     oy+dy,  oz+dz ],
    ])
    # caras (listas de vértices)
    faces = [
        [v[j] for j in [0,1,2,3]],  # fondo
        [v[j] for j in [4,5,6,7]],  # techo
        [v[j] for j in [0,1,5,4]],  # frente
        [v[j] for j in [2,3,7,6]],  # atrás
        [v[j] for j in [1,2,6,5]],  # derecha
        [v[j] for j in [0,3,7,4]],  # izquierda
    ]
    poly = Poly3DCollection(faces, facecolors=color, linewidths=linewidth, edgecolors=edgecolor, alpha=alpha)
    ax.add_collection3d(poly)
    return v  # devolvemos vértices si hace falta

def set_axes_equal(ax):
    """Asegura proporción igual en un eje 3D (no nativo en matplotlib)."""
    x_limits = ax.get_xlim3d()
    y_limits = ax.get_ylim3d()
    z_limits = ax.get_zlim3d()
    x_range = abs(x_limits[1] - x_limits[0])
    x_middle = np.mean(x_limits)
    y_range = abs(y_limits[1] - y_limits[0])
    y_middle = np.mean(y_limits)
    z_range = abs(z_limits[1] - z_limits[0])
    z_middle = np.mean(z_limits)
    plot_radius = 0.5*max([x_range, y_range, z_range])
    ax.set_xlim3d([x_middle - plot_radius, x_middle + plot_radius])
    ax.set_ylim3d([y_middle - plot_radius, y_middle + plot_radius])
    ax.set_zlim3d([z_middle - plot_radius, z_middle + plot_radius])

def plot_difference_of_cubes(x=6, y=3, show_labels=True):
    if not (x > y):
        raise ValueError("Se requiere x > y para esta representación geométrica.")
    fig = plt.figure(figsize=(10,9))
    ax = fig.add_subplot(111, projection='3d')

    # --- Cubo grande (solo aristas) ---
    # Dibujar el cubo de lado x como contorno (sin relleno, para enmarcar)
    draw_cuboid(ax, (0,0,0), (x,x,x), color=(0,0,0,0), alpha=0, edgecolor='k', linewidth=2.0)

    # --- Cubo pequeño y su etiqueta ---
    draw_cuboid(ax, (0,0,0), (y,y,y), color='green', alpha=0.6, edgecolor='k', linewidth=1.2)
    # centro del cubo pequeño
    cx_sm, cy_sm, cz_sm = y/2, y/2, y/2
    ax.text(cx_sm, cy_sm, cz_sm, r"$y^3$", color='white', fontsize=12, ha='center', va='center', weight='bold')

    # --- Tres bloques que conforman x^3 - y^3 ---
    # 1) Bloque A: x en [y,x], y in [0,x], z in [0,x]. dims: (x-y, x, x)
    A_origin = (y, 0, 0)
    A_size = (x - y, x, x)
    draw_cuboid(ax, A_origin, A_size, color='tab:blue', alpha=0.35, edgecolor='k', linewidth=1.0)
    A_center = (A_origin[0] + A_size[0]/2, A_origin[1] + A_size[1]/2, A_origin[2] + A_size[2]/2)

    # 2) Bloque B: x in [0,y], y in [y,x], z in [0,x]. dims: (y, x-y, x)
    B_origin = (0, y, 0)
    B_size = (y, x - y, x)
    draw_cuboid(ax, B_origin, B_size, color='tab:blue', alpha=0.35, edgecolor='k', linewidth=1.0)
    B_center = (B_origin[0] + B_size[0]/2, B_origin[1] + B_size[1]/2, B_origin[2] + B_size[2]/2)

    # 3) Bloque C: x in [0,y], y in [0,y], z in [y,x]. dims: (y, y, x-y)
    C_origin = (0, 0, y)
    C_size = (y, y, x - y)
    draw_cuboid(ax, C_origin, C_size, color='tab:blue', alpha=0.35, edgecolor='k', linewidth=1.0)
    C_center = (C_origin[0] + C_size[0]/2, C_origin[1] + C_size[1]/2, C_origin[2] + C_size[2]/2)

    # Etiquetas de volúmenes en el interior (contraste según color)
    ax.text(A_center[0], A_center[1], A_center[2], r"$(x-y)x^2$", color='black', fontsize=10, ha='center', va='center')
    ax.text(B_center[0], B_center[1], B_center[2], r"$(x-y)xy$", color='black', fontsize=10, ha='center', va='center')
    ax.text(C_center[0], C_center[1], C_center[2], r"$(x-y)y^2$", color='black', fontsize=10, ha='center', va='center')

    # --- Líneas de cota (dimensiones x, y, z) ---
    d = 0.12 * x  # desplazamiento visual para las cotas
    # línea para x (en z = -d, y = -d)
    ax.plot([0, x], [-d, -d], [-d, -d], color='k', linewidth=1.5)
    ax.plot([0, 0], [-d, -d], [-d*0.9, -d*1.1], color='k', linewidth=1.2)  # ticks
    ax.plot([x, x], [-d, -d], [-d*0.9, -d*1.1], color='k', linewidth=1.2)
    ax.text(x/2, -d, -d, r"$x$", fontsize=12, ha='center', va='center')

    # línea para y (en x = -d, z = -d)
    ax.plot([-d, -d], [0, x], [-d, -d], color='k', linewidth=1.5)
    ax.plot([-d*0.9, -d*1.1], [0, 0], [-d, -d], color='k', linewidth=1.2)
    ax.plot([-d*0.9, -d*1.1], [x, x], [-d, -d], color='k', linewidth=1.2)
    ax.text(-d, x/2, -d, r"$x$", fontsize=12, ha='center', va='center')  # mostrar x en la cota global

    # línea para z (en x = -d, y = -d)
    ax.plot([-d, -d], [-d, -d], [0, x], color='k', linewidth=1.5)
    ax.plot([-d*0.9, -d*1.1], [-d, -d], [0, 0], color='k', linewidth=1.2)
    ax.plot([-d*0.9, -d*1.1], [-d, -d], [x, x], color='k', linewidth=1.2)
    ax.text(-d, -d, x/2, r"$x$", fontsize=12, ha='center', va='center')

    # cota para y (señalada en el eje x en el frente): desde 0 hasta y (en y = -1.7*d to make visible)
    ax.plot([0, y], [-1.6*d, -1.6*d], [0, 0], color='tab:gray', linewidth=2.0)
    ax.text(y/2, -1.6*d, 0, r"$y$", fontsize=12, ha='center', va='center')

    # --- Estética y leyenda ---
    proxies = [
        Patch(facecolor='green', edgecolor='k', label=r"$y^3$"),
        Patch(facecolor='tab:blue', edgecolor='k', label=r"Bloques: $(x-y)x^2,\ (x-y)xy,\ (x-y)y^2$"),
        Patch(facecolor='none', edgecolor='k', label=r"Cubo marco: $x^3$"),
    ]
    ax.legend(handles=proxies, loc='upper left', bbox_to_anchor=(0.02, 0.98))

    # límites y etiquetas
    ax.set_xlim(-d, x + 0.6*x)
    ax.set_ylim(-d, x + 0.6*x)
    ax.set_zlim(-d, x + 0.6*x)
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_zlabel("Z")
    ax.view_init(elev=22, azim=-60)

    set_axes_equal(ax)
    plt.title("Descomposición geométrica de $x^3 - y^3$ en $y^3$ y los tres bloques restantes\n(Condición: x > y)")
    plt.savefig("diferencia_de_cubos.png", dpi=300)
    plt.show()

# Ejecutar con valores por defecto (x > y)
plot_difference_of_cubes(x=6, y=3)

# %% [markdown]
# 📌 Este código te mostrará:
#
# * Un cubo grande azul claro de lado \$x\$.
# * Un cubo pequeño naranja de lado \$y\$.
# * Tres cajas de colores (verde, púrpura y roja) que representan la descomposición del volumen \$(x-y)(x^2+xy+y^2)\$.
# * Líneas de cota rojas y azules para señalar \$x\$ y \$y\$.
#
# ¿Quieres que te prepare también la **versión interactiva con `plotly`** para que los estudiantes puedan **rotar y explorar el sólido** en Jupyter Notebook?

# %% [markdown]
# # Solución del punto geométrico (diferencia de cubos) pero con un estilo de guía pedagógica.
#
# Perfecto — te entrego la **solución redactada como guía pedagógica** lista para usar en clase: objetivos, motivación, descripción geométrica paso a paso, demostración algebraica apoyada en la figura, ejemplo numérico, actividades de aula, preguntas de evaluación y errores frecuentes. Va en español y con un tono docente, claro y directo.
#
# ---

# %% [markdown]
# # Guía pedagógica — Demostración geométrica de $x^3 - y^3 = (x-y)(x^2+xy+y^2)$ (caso $x>y$)

# %% [markdown]
# ## Objetivos
#
# 1. Que el estudiante **comprenda geométricamente** la identidad $x^3 - y^3 = (x-y)(x^2+xy+y^2)$.
# 2. Que el estudiante **relacione volúmenes** de prismas rectangulares con la factorización de un polinomio.
# 3. Que el estudiante **practique traducción** entre situaciones geométricas y expresiones algebraicas.

# %% [markdown]
# ## Nivel y prerequisitos
#
# * Curso: Álgebra elemental / Álgebra intermedia (primer semestre).
# * Prerrequisitos: operaciones con potencias, volúmenes de prismas/cubos, notación algebraica básica.

# %% [markdown]
# ## Materiales sugeridos
#
# * Pizarra y rotuladores / proyector con imagen 3D (el gráfico que hemos preparado).
# * Cubos físicos (si hay) o bloques tipo Lego para modelar $x$ y $y$.
# * Hojas de trabajo con la figura esquemática (cubo de lado $x$ y subcubo de lado $y$).
#
# ---

# %% [markdown]
# ## Motivación (5 min)
#
# Plantea el problema: “¿Cómo expresar la diferencia de volúmenes entre dos cubos —uno de lado $x$ y otro de lado $y$ (con $x>y$)— como un producto de factores más sencillos?”
# Invita a los estudiantes a proponer posibles estrategias: resta directa, factorizar algebraicamente, o visualizar geométricamente.
#
# ---

# %% [markdown]
# ## Descripción geométrica (10 min)
#
# 1. Dibuja (o muestra) el **cubo grande** de lado $x$. Ese cubo tiene volumen $x^3$.
# 2. Marca en la esquina inferior el **cubo pequeño** de lado $y$ (misma orientación). Ese cubo tiene volumen $y^3$.
# 3. Observa que al quitar el cubo pequeño del grande, queda un “recorte” que se puede **descomponer en 3 bloques rectangulares** (no solapantes) que, sumados, completan la diferencia de volúmenes $x^3 - y^3$.
#
#    * Bloque A: el bloque que queda a lo largo del eje $x$ cuando cortas en $x=y$.
#    * Bloque B: el bloque que queda a lo largo del eje $y$ cuando cortas en $y=y$.
#    * Bloque C: el bloque que queda sobre el eje $z$ cuando cortas en $z=y$.
#
# (Usa la figura 3D: colorea el cubo $y^3$ y los tres bloques restantes con colores distintos para que se vean separados.)
#
# ---

# %% [markdown]
# ## Cálculo de volúmenes de las piezas (10–15 min)
#
# Explica cada bloque en términos de dimensiones y volumen:
#
# * **Cubo pequeño**: aristas $y,y,y$ → volumen $V_{\text{pequeño}} = y^3$.
#
# * **Bloque A** (colocado junto al eje $x$, origen en $(y,0,0)$ en la figura):
#
#   * Dimensiones: $(x-y)$ en dirección $x$, $x$ en dirección $y$, $x$ en dirección $z$.
#   * Volumen: $V_A = (x-y)\cdot x \cdot x = (x-y)x^2$.
#
# * **Bloque B** (junto al eje $y$, origen en $(0,y,0)$):
#
#   * Dimensiones: $y$ en $x$, $(x-y)$ en $y$, $x$ en $z$.
#   * Volumen: $V_B = y\cdot (x-y)\cdot x = (x-y)xy$.
#
# * **Bloque C** (eje $z$, origen en $(0,0,y)$):
#
#   * Dimensiones: $y$ en $x$, $y$ en $y$, $(x-y)$ en $z$.
#   * Volumen: $V_C = y\cdot y \cdot (x-y) = (x-y)y^2$.
#
# **Observación importante (geometría):** las tres piezas $A,B,C$ son disjuntas (no se solapan) y junto al cubo pequeño ocupan exactamente el volumen del cubo grande.
#
# ---
#
# ## Suma y factor común (5 min)
#
# Suma las tres piezas que representan la diferencia de volúmenes:
#
# $$
# x^3 - y^3 = V_A + V_B + V_C
# = (x-y)x^2 + (x-y)xy + (x-y)y^2.
# $$
#
# Factor común $(x-y)$:
#
# $$
# x^3 - y^3 = (x-y)\bigl(x^2 + xy + y^2\bigr).
# $$
#
# Caja final: $\boxed{x^3 - y^3 = (x-y)(x^2+xy+y^2)}$. Esto demuestra la identidad mediante la descomposición geométrica.
#
# ---
#
# ## Ejemplo numérico (5 min)
#
# Toma $x=6$, $y=3$ (como en el gráfico):
#
# * $x^3 = 216$, $y^3 = 27$ → diferencia $216-27=189$.
# * Volúmenes de bloques:
#
#   * $V_A=(6-3)6^2 = 3\cdot36 = 108$.
#   * $V_B=(6-3)\cdot6\cdot3 = 3\cdot18 = 54$.
#   * $V_C=(6-3)\cdot3^2 = 3\cdot9 = 27$.
# * Suma: $108+54+27 = 189$ (coincide).
# * Factorización: $(6-3)(36+18+9) = 3\cdot63 = 189$.
#
# Pide a los estudiantes verificar las cuentas.
#
# ---
#
# ## Actividades propuestas en clase (20–25 min)
#
# 1. **Trabajo en parejas (10 min)**
#
#    * Entregar a cada pareja una hoja con la figura en blanco y valores numéricos para $x$ y $y$.
#    * Pedir que marquen las tres piezas, calculen volúmenes y verifiquen la igualdad numérica.
#
# 2. **Discusión guiada (5–7 min)**
#
#    * Preguntas: ¿Por qué son disjuntas las tres piezas? ¿Qué ocurre si $x=y$? (respuesta: diferencia 0, las piezas degeneran). ¿Qué pasa si $y=0$? (se recupera $x^3$).
#
# 3. **Variante algebraica (5–8 min)**
#
#    * Solicitar que los estudiantes deduzcan la identidad algebraicamente (sustracción de cubos y factorización) y comparen ambos enfoques: geométrico vs algebraico.
#
# ---
#
# ## Preguntas de evaluación (para examen o tarea)
#
# 1. (Conceptual) Explique en pocas frases cómo la descomposición geométrica prueba la identidad. (3 pts)
# 2. (Cálculo) Para $x=8,y=5$ calcule $x^3-y^3$ y verifique la suma de volúmenes de las tres piezas. (4 pts)
# 3. (Razonamiento) ¿Se puede hacer la misma descomposición para $y>x$? Explique. (3 pts)
# 4. (Extensión) Describa cómo sería la descomposición geométrica para $x^3+y^3$ (pista: suma de cubos requiere otro tipo de partición). (4 pts)
#
# ---
#
# ## Errores frecuentes y cómo corregirlos
#
# * **Error:** contar mal las dimensiones de algún bloque (p. ej. tomar $x-y$ en la dirección equivocada).
#   **Corrección:** pedir que identifiquen las coordenadas de origen de cada bloque en la figura y anoten sus tres dimensiones antes de multiplicar.
# * **Error:** pensar que las tres piezas se solapan.
#   **Corrección:** mostrar el cubo pequeño y las piezas sobre la figura y subrayar que cada pieza ocupa una “tira” perpendicular a un eje distinto sin intersección.
# * **Error aritmético:** suma incorrecta de volúmenes numéricos.
#   **Corrección:** usar calculadora o verificar por factorización $(x-y)(x^2+xy+y^2)$ como comprobante.
#
# ---
#
# ## Extensiones y actividades extra
#
# * Hacer la **versión interactiva** (Plotly o bloques físicos) y pedir a los estudiantes que roten la figura para entender la posición de cada bloque.
# * Pedir que intenten una **demostración análoga** para potencias mayores (p. ej. $x^4-y^4$) y comparen con la factorización algebraica conocida.
# * Investigar la **suma de cubos** $x^3+y^3$ y su factorización $(x+y)(x^2-xy+y^2)$ desde un punto de vista geométrico (requiere imaginación/otra partición).
#
# ---
#
# ## Cierre (5 min)
#
# Repasar la identidad alcanzada y su significado: la factorización no es sólo manipulación simbólica —tiene interpretación geométrica clara cuando trabajamos con volúmenes. Anima a los estudiantes a conservar la figura como referencia para futuras factorizaciones.
#
# ---
#
# Si lo deseas, puedo entregarte:
#
# * la **hoja de trabajo** lista para imprimir con la figura y espacios para cálculos;
# * la **versión en .docx** con la guía y la figura incluida; o
# * una **presentación (PowerPoint)** corta con la animación paso a paso de la partición geométrica. ¿Cuál prefieres?
