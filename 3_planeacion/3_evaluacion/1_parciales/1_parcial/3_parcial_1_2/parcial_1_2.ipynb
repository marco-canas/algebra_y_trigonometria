# %% [markdown]
# Perfecto, Marco 👍. Te armo un **diseño de parcial** con la **estructura IMUA** que mencionas, pero **adaptado a las secciones 1.1–1.4 del Swokowski (13ª edición)**.
#
# ---

# %% [markdown]
# # **Parcial de Álgebra y Trigonometría – Primer Semestre**
#
# **Duración**: 2 horas
# **Puntaje total**: 100 puntos (20 puntos por ítem)
# **Temas evaluados**:
#
# * 1.1 Números reales
# * 1.2 Exponentes y radicales
# * 1.3 Expresiones algebraicas
# * 1.4 Expresiones fraccionarias
#
# ---
#
# ### **1. Teoría y Definiciones (20 puntos)**
#
# Responda de forma clara y justificada:
#
# a) (5 pts) Defina el conjunto de los números reales y explique cómo se construyen a partir de los números racionales e irracionales.
# b) (5 pts) ¿Qué significa que una expresión esté “racionalizada”? Dé un ejemplo sencillo.
# c) (5 pts) ¿Cuál es la diferencia entre una factorización y una descomposición en fracciones parciales?
# d) (5 pts) Justifique: ¿Por qué no está definida la operación $\sqrt{-9}$ dentro del conjunto de los números reales?
#
# ---
#
# ### **2. Resolución de Ecuaciones y Expresiones (20 puntos)**
#
# Resuelva paso a paso:
#
# a) (10 pts) Resuelva la ecuación radical:
#
# $$
# \sqrt{x + 5} = x - 1
# $$
#
# Indique y descarte las soluciones extraviadas si las hay.
#
# b) (10 pts) Simplifique la siguiente expresión con exponentes:
#
# $$
# \frac{a^{\frac{3}{2}} \cdot a^{\frac{1}{3}}}{a^{\frac{5}{6}}}
# $$
#
# ---
#
# ### **3. Productos Notables y Factorización (20 puntos)**
#
# a) (10 pts) Expanda y simplifique usando productos notables:
#
# $$
# (x + 2y)^3
# $$
#
# b) (10 pts) Factorice completamente:
#
# $$
# 6x^2 - 7x - 3
# $$
#
# ---
#
# ### **4. Expresiones Fraccionarias (20 puntos)**
#
# a) (10 pts) Simplifique la siguiente fracción algebraica:
#
# $$
# \frac{x^2 - 9}{x^2 - 6x + 9}
# $$
#
# b) (10 pts) Realice la operación:
#
# $$
# \frac{2}{x+3} + \frac{3}{x-3}
# $$
#
# ---
#
# ### **5. Problema de Aplicación y Análisis (20 puntos)**
#
# Un depósito de agua tiene la forma de un prisma rectangular con base cuadrada. El área de la base se expresa como:
#
# $$
# A(x) = x^2 + 4x + 4
# $$
#
# y la altura como
#
# $$
# h(x) = x + 2.
# $$
#
# a) (10 pts) Exprese el volumen $V(x)$ del depósito como producto algebraico y simplifíquelo.
# b) (10 pts) Para $x = 3$, calcule el volumen exacto y explique brevemente qué papel juegan la factorización y la simplificación de expresiones algebraicas en este tipo de problemas aplicados.
#
# ---
#
# ### **Notas para el estudiante**
#
# * Muestre **todos los pasos de sus procedimientos**.
# * Se evaluará tanto la **respuesta final correcta** como la **claridad en el razonamiento**.
# * Use notación matemática adecuada.
#
# ---
#
# 📌 Con esto tendrías un parcial **muy alineado con el estilo IMUA**:
#
# * Inicio conceptual (item 1).
# * Procedimientos técnicos (items 2–4).
# * Un problema aplicado integrador (item 5).
#
# ¿Quieres que además te prepare la **rúbrica de calificación** (criterios de claridad, procedimiento, notación, resultado) para que tus estudiantes tengan lineamientos claros?
