# %% [markdown]
# Perfecto, Marco 🙌. Tomando la **estructura IMUA** que planteas, aquí tienes el **diseño de parcial** ajustado a las secciones 1.1–1.4 del Swokowski (13ª ed.):
#
# ---
#
# # **Parcial de Álgebra y Trigonometría – Primer Semestre**
#
# **Duración**: 2 horas
# **Puntos totales**: 100 (20 puntos por ítem).
#
# ---
#
# ### **1. Teoría y Definiciones (20 puntos)**
#
# Responda brevemente y con precisión:
#
# a) Defina el **conjunto de los números reales**. ¿Qué subconjuntos lo componen? (4 pts)
# b) ¿Qué significa que un exponente sea racional? Dé un ejemplo. (4 pts)
# c) ¿Qué es un producto notable? Mencione al menos dos con su fórmula. (4 pts)
# d) Explique por qué no es posible dividir entre cero en una fracción algebraica. (4 pts)
# e) ¿Qué se entiende por “racionalizar” un denominador? (4 pts)
#
# ---
#
# ### **2. Resolución de Ecuaciones y Simplificación (20 puntos)**
#
# Resuelva y simplifique:
#
# a) Simplifique la expresión:
#
# $$
# \frac{\sqrt{18}}{\sqrt{2}}
# $$
#
# (5 pts)
#
# b) Racionalice el denominador y simplifique:
#
# $$
# \frac{5}{2 + \sqrt{3}}
# $$
#
# (5 pts)
#
# c) Simplifique completamente:
#
# $$
# \frac{x^2 - 9}{x^2 - x - 6}
# $$
#
# (5 pts)
#
# d) Resuelva la ecuación:
#
# $$
# 3x^2 - 12 = 0
# $$
#
# (5 pts)
#
# ---
#
# ### **3. Aplicación de Productos Notables y Factorización (20 puntos)**
#
# a) Expanda usando productos notables:
#
# $$
# (x + 2)^2
# $$
#
# (5 pts)
#
# b) Expanda y simplifique:
#
# $$
# (x - 3)(x + 3)
# $$
#
# (5 pts)
#
# c) Factorice completamente:
#
# $$
# x^3 - 27
# $$
#
# (5 pts)
#
# d) Factorice completamente y simplifique:
#
# $$
# \frac{x^2 - 16}{x^2 + 5x + 6}
# $$
#
# (5 pts)
#
# ---
#
# ### **4. Expresiones Fraccionarias: Operaciones (20 puntos)**
#
# a) Simplifique la fracción algebraica:
#
# $$
# \frac{x^2 - 4}{x^2 + 2x}
# $$
#
# (5 pts)
#
# b) Efectúe la operación y simplifique:
#
# $$
# \frac{x}{x+2} + \frac{4}{x-2}
# $$
#
# (5 pts)
#
# c) Multiplique y simplifique:
#
# $$
# \frac{x^2 - 9}{x^2 - x - 6} \cdot \frac{x^2 - 4}{x^2 - 3x}
# $$
#
# (5 pts)
#
# d) Divida y simplifique:
#
# $$
# \frac{x^2 - 25}{x^2 + 6x + 5} \div \frac{x^2 + 3x + 2}{x^2 - 9}
# $$
#
# (5 pts)
#
# ---
#
# ### **5. Desarrollo y Análisis Integrador (20 puntos)**
#
# Considere la expresión algebraica:
#
# $$
# f(x) = \frac{x^2 - 4}{x^2 - 5x + 6}
# $$
#
# a) Factorice numerador y denominador, y simplifique la fracción. (6 pts)
# b) Determine los valores de $x$ para los cuales la expresión no está definida. (6 pts)
# c) Analice el comportamiento de la función cuando $x \to \infty$. (4 pts)
# d) Esboce un gráfico cualitativo de la función simplificada, indicando las restricciones. (4 pts)
#
# ---
#
# ## **Notas adicionales**
#
# * **Estilo IMUA**: Preguntas claras, notación rigurosa, pasos justificados.
# * **Secuencia de dificultad**: de mecánico a integrador.
# * **Balance**: conceptos (ítem 1), procedimientos (ítems 2–4), análisis crítico (ítem 5).
#
# ---
#
# ¿Quieres que además te prepare la **rúbrica de calificación** (criterios por ítem) para que quede listo para usar en tu clase?
