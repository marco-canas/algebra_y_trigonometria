# %% [markdown]
# ### **Plan de Desarrollo de Contenidos del Curso de Álgebra y Trigonometría**
# **Universidad de Antioquia**
# **Fecha de inicio: Martes, 5 de agosto de 2025**
# **Horario: Martes y miércoles, 9:00 - 11:00 a.m.**
# **Total horas: 64**
# - Horas para parciales: 8 (4 parciales × 2 horas cada uno).
# - Horas para quices: 3 (6 quices × 0.5 horas cada uno).
# - Horas para desarrollo de contenidos: 53 (56 - 3 horas de quices).
#
# ---
#
# ### **Distribución Temática por Fechas**
#
# #### **Unidad 1: Aritmética** (12 horas)
# **Objetivos:**
# - Dominar operaciones con números reales, potenciación, radicación y expresiones algebraicas.
# - Resolver ecuaciones, inecuaciones y problemas con razones y proporciones.
#
# | **Fecha**       | **Temas**                                                                 | **Actividades**                     |
# |-----------------|--------------------------------------------------------------------------|-------------------------------------|
# | **5/08/2025**  | Números reales, potenciación, radicación.                                | Clase teórica + ejercicios prácticos. |
# | **6/08/2025**  | Expresiones algebraicas y operaciones. Productos notables.               | Taller en clase.                    |
# | **12/08/2025** | Factorización. Números complejos.                                        | Clase magistral + problemas.        |
# | **13/08/2025** | Ecuaciones algebraicas. Inecuaciones.                                    | Ejercicios grupales.                |
# | **19/08/2025** | Razones, proporciones y porcentajes.                                     | **Quiz 1** (0.5 h) + práctica.      |
# | **20/08/2025** | Repaso y resolución de dudas.                                            | **Parcial 1** (2 h, últimos 30 min). |
#
# ---
#
# #### **Unidad 2: Funciones** (14 horas)
# **Objetivos:**
# - Comprender relaciones, funciones, dominio, rango y transformaciones.
# - Analizar funciones exponenciales, logarítmicas y sus aplicaciones.
#
# | **Fecha**       | **Temas**                                                                 | **Actividades**                     |
# |-----------------|--------------------------------------------------------------------------|-------------------------------------|
# | **26/08/2025** | Rectas, relaciones, funciones: dominio y rango.                          | Clase teórica + GeoGebra.           |
# | **27/08/2025** | Gráficas, operaciones y composición de funciones.                        | Taller gráfico.                     |
# | **2/09/2025**  | Funciones por tramos, pares/impares, biyectivas.                         | Ejercicios aplicados.               |
# | **3/09/2025**  | Funciones invertibles. Funciones exponenciales.                          | **Quiz 2** (0.5 h) + problemas.     |
# | **9/09/2025**  | Funciones logarítmicas y ecuaciones asociadas.                           | Casos prácticos (crecimiento bacteriano). |
# | **10/09/2025** | Repaso y aplicaciones.                                                   | **Parcial 2** (2 h).                |
#
# ---
#
# #### **Unidad 3: Polinomios** (14 horas)
# **Objetivos:**
# - Dominar álgebra de polinomios, teoremas fundamentales y sistemas de ecuaciones.
# - Resolver problemas con progresiones aritméticas y geométricas.
#
# | **Fecha**       | **Temas**                                                                 | **Actividades**                     |
# |-----------------|--------------------------------------------------------------------------|-------------------------------------|
# | **16/09/2025** | Funciones polinomiales. Algoritmo de la división.                        | Clase magistral.                    |
# | **17/09/2025** | Teorema fundamental del álgebra. Ceros racionales/irracionales.          | Taller + discusión.                 |
# | **23/09/2025** | Sistemas de ecuaciones. Fracciones parciales.                            | **Quiz 3** (0.5 h) + ejercicios.    |
# | **24/09/2025** | Progresiones aritméticas y geométricas.                                  | Problemas aplicados (finanzas).     |
# | **30/09/2025** | Sumas y productos. Repaso general.                                       | Trabajo en equipo.                  |
# | **1/10/2025**  | **Parcial 3** (2 h).                                                    | Evaluación escrita.                 |
#
# ---
#
# #### **Unidad 4: Trigonometría** (13 horas)
# **Objetivos:**
# - Analizar funciones trigonométricas, identidades y teoremas.
# - Aplicar la ley de senos/cosenos y el teorema de Moivre.
#
# | **Fecha**       | **Temas**                                                                 | **Actividades**                     |
# |-----------------|--------------------------------------------------------------------------|-------------------------------------|
# | **7/10/2025**  | Ángulos. Funciones trigonométricas de ángulos agudos.                    | Clase teórica + círculo unitario.   |
# | **8/10/2025**  | Funciones trigonométricas de números reales. Gráficas.                    | GeoGebra + ejercicios.              |
# | **14/10/2025** | Funciones inversas. Identidades trigonométricas.                          | **Quiz 4** (0.5 h) + demostraciones.|
# | **15/10/2025** | Ley de senos y cosenos. Aplicaciones.                                    | Problemas de navegación/ingeniería. |
# | **21/10/2025** | Forma polar de números complejos. Teorema de Moivre.                      | **Quiz 5** (0.5 h) + práctica.      |
# | **22/10/2025** | Repaso general.                                                          | **Parcial 4** (2 h).                |
#
# ---
#
# ### **Detalles Adicionales**
# - **Quices:** Distribuidos en las unidades para evaluar progreso (19/08, 3/09, 23/09, 14/10, 21/10).
# - **Parciales:** Siempre en la última sesión de cada unidad (20/08, 10/09, 1/10, 22/10).
# - **Flexibilidad:** 3 horas libres para ajustes (repasos, actividades prácticas o internacionalización).
#
# Este plan asegura el cumplimiento de los créditos, la cobertura de contenidos y la preparación para evaluaciones.

# %% [markdown]
# Aquí tienes un script de Python que utiliza la biblioteca `python-docx` para convertir el plan de desarrollo del curso en un archivo `.docx` (Word) con formato estructurado. El script organiza el contenido por unidades, fechas, temas y actividades, y lo guarda en un archivo listo para compartir.
#
# ---
#
# ### **Script Python para Generar el Archivo DOCX**

# %%
from docx import Document
from docx.shared import Pt, RGBColor
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT
from docx.enum.table import WD_TABLE_ALIGNMENT

# Crear un nuevo documento de Word
doc = Document()

# Configuración básica del documento
style = doc.styles['Normal']
font = style.font
font.name = 'Calibri'
font.size = Pt(11)

# Título del documento
title = doc.add_heading('Plan de Desarrollo - Álgebra y Trigonometría', level=1)
title.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

# Subtítulo con información del curso
subtitle = doc.add_paragraph()
subtitle.add_run('Universidad de Antioquia - Facultad de Ciencias Exactas y Naturales\n')
subtitle.add_run('Docente: [Tu Nombre]\n')
subtitle.add_run('Coordinador: Jairo Eloy Castellanos\n')
subtitle.add_run('Fecha de inicio: 5 de agosto de 2025 | Horario: Martes y miércoles, 9:00 - 11:00 a.m.\n')
subtitle.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

# Sección de resumen del curso
doc.add_heading('Resumen del Curso', level=2)
summary = doc.add_paragraph()
summary.add_run('Total horas: 64\n')
summary.add_run('• Horas para parciales: 8 (4 parciales × 2 horas cada uno).\n')
summary.add_run('• Horas para quices: 3 (6 quices × 0.5 horas cada uno).\n')
summary.add_run('• Horas para desarrollo de contenidos: 53.\n')

# Datos estructurados del plan de desarrollo (por unidad)
unidades = [
    {
        "nombre": "Unidad 1: Aritmética",
        "objetivo": "Dominar operaciones con números reales, potenciación, radicación y expresiones algebraicas. Resolver ecuaciones, inecuaciones y problemas con razones y proporciones.",
        "sesiones": [
            {"fecha": "5/08/2025", "tema": "Números reales, potenciación, radicación.", "actividad": "Clase teórica + ejercicios prácticos."},
            {"fecha": "6/08/2025", "tema": "Expresiones algebraicas y operaciones. Productos notables.", "actividad": "Taller en clase."},
            {"fecha": "12/08/2025", "tema": "Factorización. Números complejos.", "actividad": "Clase magistral + problemas."},
            {"fecha": "13/08/2025", "tema": "Ecuaciones algebraicas. Inecuaciones.", "actividad": "Ejercicios grupales."},
            {"fecha": "19/08/2025", "tema": "Razones, proporciones y porcentajes.", "actividad": "Quiz 1 (0.5 h) + práctica."},
            {"fecha": "20/08/2025", "tema": "Repaso y resolución de dudas.", "actividad": "Parcial 1 (2 h, últimos 30 min)."}
        ]
    },
    {
        "nombre": "Unidad 2: Funciones",
        "objetivo": "Comprender relaciones, funciones, dominio, rango y transformaciones. Analizar funciones exponenciales, logarítmicas y sus aplicaciones.",
        "sesiones": [
            {"fecha": "26/08/2025", "tema": "Rectas, relaciones, funciones: dominio y rango.", "actividad": "Clase teórica + GeoGebra."},
            {"fecha": "27/08/2025", "tema": "Gráficas, operaciones y composición de funciones.", "actividad": "Taller gráfico."},
            {"fecha": "2/09/2025", "tema": "Funciones por tramos, pares/impares, biyectivas.", "actividad": "Ejercicios aplicados."},
            {"fecha": "3/09/2025", "tema": "Funciones invertibles. Funciones exponenciales.", "actividad": "Quiz 2 (0.5 h) + problemas."},
            {"fecha": "9/09/2025", "tema": "Funciones logarítmicas y ecuaciones asociadas.", "actividad": "Casos prácticos (crecimiento bacteriano)."},
            {"fecha": "10/09/2025", "tema": "Repaso y aplicaciones.", "actividad": "Parcial 2 (2 h)."}
        ]
    },
    {
        "nombre": "Unidad 3: Polinomios",
        "objetivo": "Dominar álgebra de polinomios, teoremas fundamentales y sistemas de ecuaciones. Resolver problemas con progresiones aritméticas y geométricas.",
        "sesiones": [
            {"fecha": "16/09/2025", "tema": "Funciones polinomiales. Algoritmo de la división.", "actividad": "Clase magistral."},
            {"fecha": "17/09/2025", "tema": "Teorema fundamental del álgebra. Ceros racionales/irracionales.", "actividad": "Taller + discusión."},
            {"fecha": "23/09/2025", "tema": "Sistemas de ecuaciones. Fracciones parciales.", "actividad": "Quiz 3 (0.5 h) + ejercicios."},
            {"fecha": "24/09/2025", "tema": "Progresiones aritméticas y geométricas.", "actividad": "Problemas aplicados (finanzas)."},
            {"fecha": "30/09/2025", "tema": "Sumas y productos. Repaso general.", "actividad": "Trabajo en equipo."},
            {"fecha": "1/10/2025", "tema": "Parcial 3 (2 h).", "actividad": "Evaluación escrita."}
        ]
    },
    {
        "nombre": "Unidad 4: Trigonometría",
        "objetivo": "Analizar funciones trigonométricas, identidades y teoremas. Aplicar la ley de senos/cosenos y el teorema de Moivre.",
        "sesiones": [
            {"fecha": "7/10/2025", "tema": "Ángulos. Funciones trigonométricas de ángulos agudos.", "actividad": "Clase teórica + círculo unitario."},
            {"fecha": "8/10/2025", "tema": "Funciones trigonométricas de números reales. Gráficas.", "actividad": "GeoGebra + ejercicios."},
            {"fecha": "14/10/2025", "tema": "Funciones inversas. Identidades trigonométricas.", "actividad": "Quiz 4 (0.5 h) + demostraciones."},
            {"fecha": "15/10/2025", "tema": "Ley de senos y cosenos. Aplicaciones.", "actividad": "Problemas de navegación/ingeniería."},
            {"fecha": "21/10/2025", "tema": "Forma polar de números complejos. Teorema de Moivre.", "actividad": "Quiz 5 (0.5 h) + práctica."},
            {"fecha": "22/10/2025", "tema": "Repaso general.", "actividad": "Parcial 4 (2 h)."}
        ]
    }
]

# Generar contenido para cada unidad
for unidad in unidades:
    doc.add_heading(unidad["nombre"], level=2)
    doc.add_paragraph(f"Objetivo: {unidad['objetivo']}")
    
    # Crear tabla para las sesiones
    table = doc.add_table(rows=1, cols=3)
    table.style = 'Light Shading'
    table.alignment = WD_TABLE_ALIGNMENT.CENTER
    
    # Encabezados de la tabla
    hdr_cells = table.rows[0].cells
    hdr_cells[0].text = "Fecha"
    hdr_cells[1].text = "Tema"
    hdr_cells[2].text = "Actividad"
    
    # Llenar la tabla con los datos de las sesiones
    for sesion in unidad["sesiones"]:
        row_cells = table.add_row().cells
        row_cells[0].text = sesion["fecha"]
        row_cells[1].text = sesion["tema"]
        row_cells[2].text = sesion["actividad"]

    doc.add_paragraph()  # Espacio entre unidades

# Guardar el documento
doc.save("Plan_Desarrollo_Algebra_Trigonometria.docx")
print("¡Documento generado con éxito! (Plan_Desarrollo_Algebra_Trigonometria.docx)")
# Out:
# ¡Documento generado con éxito! (Plan_Desarrollo_Algebra_Trigonometria.docx)

# %% [markdown]
# ---
#
# ### **Instrucciones para Ejecutar el Script**
# 1. **Requisitos previos**:
#    - Instalar la biblioteca `python-docx` con:
#      ```bash
#      pip install python-docx
#      ```

# %% [markdown]
# 2. **Pasos**:
#    - Copia el script en un archivo `.py` (ej: `generar_plan.py`).
#    - Ejecútalo con Python:
#      ```bash
#      python generar_plan.py
#      ```
#    - El archivo `Plan_Desarrollo_Algebra_Trigonometria.docx` se generará automáticamente.
#
# ---

# %% [markdown]
# ### **Resultado Esperado**
# El documento tendrá:
# - **Portada** con título, información del curso y resumen.
# - **Secciones por unidad** con objetivos y tablas de sesiones (fecha, tema, actividad).
# - **Formato profesional**: tablas sombreadas, alineación centrada y fuente Calibri.
#
# ¡Listo para compartir con estudiantes y el coordinador! 📅📚
